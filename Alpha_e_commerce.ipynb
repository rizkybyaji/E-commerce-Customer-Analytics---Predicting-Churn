# %% [markdown]
# # **E-commerce Customer Analytics: Predicting Churn**
# ### Created By : Fauzi Achmad, Hilmi Tito, M Rizky Bayu Aji

# %% [markdown]
# ## Business Problem Understanding

# %% [markdown]
# **Context**
# Dalam dunia e-commerce yang sangat kompetitif, **e-commerce** Alpha, sebuah platform yang baru didirikan, berupaya menganalisis perilaku pelanggan untuk meningkatkan retensi pelanggan. Dalam banyak penelitian bisnis dan literatur pemasaran, terdapat konsensus umum bahwa biaya untuk mendapatkan pelanggan baru jauh lebih tinggi dibandingkan dengan biaya untuk mempertahankan pelanggan lama. Sering disebut sebagai prinsip "Customer Retention vs. Acquisition", perbandingan ini sangat relevan terutama di industri e-commerce, SaaS, dan layanan berlangganan.
#
# Beberapa Referensi dan Fakta Terkait Biaya Akuisisi vs. Retensi Pelanggan:
#
# - Harvard Business Review:Menyatakan bahwa mendapatkan pelanggan baru bisa 5 hingga 25 kali lebih mahal daripada mempertahankan pelanggan yang sudah ada . Ini menunjukkan bahwa investasi dalam program retensi lebih hemat biaya daripada terus-menerus mencari pelanggan baru.
# - Bain & Company:Laporan dari Bain & Company, salah satu konsultan manajemen terkemuka: mengungkapkan bahwa meningkatkan retensi pelanggan sebesar 5% bisa meningkatkan keuntungan sebesar 25% hingga 95%. Ini dikarenakan pelanggan lama cenderung lebih sering berbelanja, berbelanja dalam jumlah yang lebih besar, dan lebih loyal.
# - Invesp: Sebuah studi dari Invesp : mendukung bahwa biaya untuk mengakuisisi pelanggan baru adalah sekitar 5 kali lebih tinggi dibandingkan dengan biaya mempertahankan pelanggan yang sudah ada. Mereka juga menemukan bahwa pelanggan setia menyumbang 16% lebih banyak terhadap keuntungan rata-rata perusahaan daripada pelanggan baru .
#
# **Oleh karena itu, Kami menganggap bahwa mempertahankan pelanggan loyal atau yang sudah ada sama pentingnya dengan mendapatkan pelanggan baru**.
#
# **Churn pelanggan** mengacu pada fenomena ketika pelanggan berhenti menggunakan produk atau layanan dari suatu perusahaan. Saat ini, churn merupakan salah satu tantangan utama yang dihadapi oleh bisnis online, khususnya e-commerce. Tingkat churn yang tinggi dapat menyebabkan hilangnya pendapatan, meningkatnya biaya pemasaran untuk memperoleh pelanggan baru, dan melemahnya loyalitas terhadap merek. Oleh karena itu, memprediksi dan mencegah churn sangat penting bagi pertumbuhan bisnis dan peningkatan profitabilitas.
#
# Banyak perusahaan seperti Netflix, Spotify, dan Zoom menggunakan indikator churn pelanggan setelah 30 hari sebagai benchmarking. Alpha e-commerce juga menerapkan indikator churn yang serupa, di mana pelanggan yang tidak melakukan transaksi atau tidak menggunakan layanan dalam 30 hari akan dianggap sebagai churn.
#
# Dengan fokus pada probabilitas churn yang saat ini berada di angka 17%, perusahaan dapat menganalisis berapa persen pelanggan yang berpotensi berhenti menggunakan layanan mereka, sehingga dapat menurunkan angka tersebut di bawah 15%. Penentuan promo juga berperan penting, di mana promo yang diberikan ditujukan untuk menarik kembali pelanggan yang berpotensi churn. Tujuan dari pendekatan ini adalah untuk melakukan langkah-langkah preventif yang dapat mengurangi tingkat churn dan mempertahankan pelanggan setia.
#
# Standar time horizon untuk churn rate dalam suatu bisnis, khususnya di sektor e-commerce atau SaaS (Software as a Service), sangat tergantung pada model bisnis dan siklus penggunaan produk atau layanan. Biasanya, time horizon yang digunakan dapat berupa bulanan atau tahunan, tergantung pada tujuan dan pola interaksi pelanggan.
#
#
# Bulanan (Monthly Churn Rate):
#
# Kapan digunakan: Time horizon bulanan sering digunakan dalam bisnis dengan siklus penjualan yang cepat, seperti e-commerce, layanan berlangganan bulanan, atau bisnis dengan transaksi yang lebih sering.
#
# Contoh penggunaan: E-commerce yang melakukan kampanye diskon atau promo besar mungkin ingin melihat Monthly Active Users (MAU) dan churn rate bulanan untuk memantau loyalitas pelanggan.
#
# Keuntungan: Analisis bulanan memungkinkan pemantauan churn rate yang lebih cepat dan responsif. kita bisa segera melihat dampak dari marketing campaign yang sedang dilakukan atau isu laiun yang mungkin membuat pelanggan berhenti berbelanja atau menggunakan layanan.
#
# Dengan demikian tingkat churn rate yang akan digunakan adalah bulanan agar dapat menangkap isu lebih cepat dari  customer yang akan berpotensi churn.
#
#
# Marketplace besar di Indonesia memiliki CAC yang lebih rendah, di kisaran Rp 100.000 hingga Rp 300.000 per pelanggan.
#
# Marketplace kecil atau niche cenderung memiliki CAC yang lebih tinggi, yaitu sekitar Rp 300.000 hingga Rp 1.000.000 per pelanggan.
#
# Untuk strategi organik, CAC bisa diturunkan ke Rp 50.000 hingga Rp 150.000 jika kampanye pemasaran organik dijalankan dengan baik.
#
#
# Target:
#
# - 0 : Pelanggan tetap menggunakan produk atau layanan.
# - 1 : Pelanggan berhenti menggunakan produk atau layanan.
#
# **Problem Statement :**
#
# Dalam industri e-commerce yang sangat kompetitif, e-commerce Alpha menghadapi tantangan utama dalam mempertahankan pelanggan mereka. Meskipun telah berhasil menarik pelanggan baru, tingkat churn yang tinggi, saat ini mencapai 17%, mengancam stabilitas pendapatan dan mengakibatkan meningkatnya biaya akuisisi pelanggan baru. Dengan churn yang tinggi, perusahaan tidak hanya kehilangan pelanggan tetapi juga menghadapi tantangan dalam mempertahankan loyalitas terhadap merek, yang secara langsung berdampak pada profitabilitas jangka panjang.
#
# E-commerce Alpha membutuhkan solusi untuk memprediksi churn pelanggan secara efektif dan mengidentifikasi faktor-faktor utama yang menyebabkan pelanggan berhenti menggunakan produk atau layanan mereka. Dengan mengembangkan model prediksi churn yang akurat, perusahaan dapat mengambil langkah-langkah strategis untuk mencegah churn dan meningkatkan retensi pelanggan, yang pada akhirnya akan meningkatkan pertumbuhan bisnis dan profitabilitas. Diharapkan, dengan implementasi solusi ini, tingkat churn dapat diturunkan dibawah angka 15%
#
# Tujuan dari analisis ini adalah untuk memprediksi apakah pelanggan akan churn atau tetap menggunakan layanan, serta memberikan rekomendasi strategi yang tepat untuk mengurangi churn berdasarkan hasil prediksi tersebut sehingga dapat mengurangi cost dari penarikan pelanggan.
#
# Saat ini rasio churn adalah 17% dimana dengan adanya solusi machine learning yang kami tawarkan, expected penurunan churn sesuai standar bisa di bawah 15%. Dengan adanya machine learning diharapkan terdapat prediksi customer mana yang akan churn berdasarkan parameter tertentu sehingga dapat ditawarkan insentif oleh perusahaan untuk meminimalisir churn.
#
# Secara deskriptif juga dianalisa variabel-variabel dengan tingkat churn yang lebih tinggi, sehingga dapat diberikan usulan untuk perbaikan kondisi eksisiting.
#
#
# **Goals :**
#
# Bangun model prediktif yang dapat mengidentifikasi pelanggan yang berisiko meninggalkan perusahaan (churn) secara akurat berdasarkan variabel yang diberikan. Hal ini dapat membantu perusahaan mengambil langkah proaktif untuk mempertahankan pelanggan tersebut dan mengurangi tingkat churn dari 17% menjadi dibawah 15%
#
# Lakukan analisis eksplorasi menyeluruh terhadap data pelanggan yang diberikan untuk mendapatkan wawasan tentang perilaku dan karakteristik pelanggan. Ini termasuk menganalisis pola dan tren dalam variabel. Analisis ini dapat membantu perusahaan memahami pelanggannya dengan lebih baik dan menginformasikan pengambilan keputusan di masa mendatang.
#
# **Analytic Approach :**
#
# Jadi yang akan kita lakukan adalah menganalisis data untuk menemukan pola yang membedakan pelanggan yang tetap menggunakan produk/layanan dan yang berhenti menggunakan produk/layanan.
#
# Kemudian kita akan membangun model klasifikasi yang akan membantu perusahaan untuk dapat memprediksi probabilitas pelanggan akan/ingin berhenti menggunakan produk/layanan perusahaan Alpha e-commerce atau tidak.
#
#
# **User:**
# User dari penggunaan model dan solusi data analytics ini adalah Customer Relationship Division, e.g Division Head, Marketing/Relationship Manager agar dapat membantu dalam menentukan strategi yang tepat untuk mengurangi churn dengan biaya yang optimal.
#
# Model digunakan setiap akhir bulan untuk menganalisa potensi customer churn. Limitasi dari model adalah adanya kriteria churn customer yang tidak membeli ulang diatas 6 bulan, serta prediktif parameter yang terbatas pada parameter terpilih pada model kami dengan variasi eksisting (apabila ada parameter atau variasi baru model belum bisa memprediksi sepenuhnya atau belum memperhitungkan parameter tersebut).

# %% [markdown]
# **Metric Valuation :**
#
#
# Type 1 error : False Positive
# - Pelanggan yang diprediksi akan churn, tetapi sebenarnya mereka tetap setia menggunakan produk atau layanan.
# - Konsekuensi: Biaya ekstra
#
# **Type 2 error : False Negative**
# - Pelanggan yang sebenarnya akan churn, tetapi model memprediksi bahwa mereka tidak akan churn.
# - Konsekuensi: Kerugian langsung, Pendapatan hilang, Loyalitas merek terancam
#
# Metrics utama adalah menggunakan rasio Recall karena bertujuan untuk mengidentifikasi customer yang akan berpotensi churn.

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# Dataset source : https://www.kaggle.com/datasets/ankitverma2010/ecommerce-customer-churn-analysis-and-prediction

# %% [markdown]
# Note :
# - Dataset tidak seimbang
# - Fitur bersifat kategori dan Numerikal
# - Setiap baris data merepresentasikan informasi terkait pelanggan

# %% [markdown]
# ### Attribute Information
#
# | Attribute | Description |
# | --- |  --- |
# | CustomerID | Unique customer ID |
# | Churn | Churn Flag |
# | Tenure | Tenure of customer in organization |
# | PreferredLoginDevice | Preferred login device of customer |
# | CityTier | City tier |
# | WarehouseToHome | Distance in between warehouse to home of customer |
# | PreferredPaymentMode | Preferred payment method of customer |
# | Gender | Gender of customer |
# | HourSpendOnApp | Number of hours spend on mobile application or website |
# | NumberOfDeviceRegistered | Total number of deceives is registered on particular customer |
# | PreferedOrderCat | Preferred order category of customer in last month |
# | SatisfactionScore | Satisfactory score of customer on service |
# | MaritalStatus | Marital status of customer |
# | NumberOfAddress | Total number of added added on particular customer |
# | Complain | Any complaint has been raised in last month |
# | OrderAmountHikeFromlastYear | Percentage increases in order from last year |
# | CouponUsed | Total number of coupon has been used in last month |
# | OrderCount | Total number of orders has been places in last month |
# | DaySinceLastOrder | Day Since last order by customer |
# | CashbackAmount | Average cashback in last month |

# %%
#Library Dasar & Visualisasi
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno
from IPython.display import display
import warnings
warnings.simplefilter(action='ignore')

# %%
# Load dataset
# df = pd.read_excel('/content/E Commerce Dataset.xlsx',  sheet_name='E Comm')
df = pd.read_excel('E Commerce Dataset.xlsx', sheet_name='E Comm')
df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
# Count and Data Type each Column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %% [markdown]
# ## Data Cleaning
#
# Ada data yang hilang/kosong dibeberapa fitur/kolom, kemudian fitur/kolom customerID tidak berguna untuk analisis dan modeling, maka kita akan memperbaiki semua datanya dan membuatnya menjadi siap pakai untuk melakukan analisa terhadap masalahnya dan juga pembuatan model machine learningnya.

# %%
listItem = []
for col in df.columns :
    listItem.append([col, df[col].dtype, df[col].isna().sum(), round((df[col].isna().sum()/len(df[col])) * 100,2),
                    df[col].nunique(), list(df[col].drop_duplicates().values)]);

dfDesc = pd.DataFrame(columns=['dataFeatures', 'dataType', 'null', 'nullPct', 'unique', 'uniqueSample'],
                     data=listItem)
dfDesc
# Out:
#                    dataFeatures dataType  null  nullPct  unique  \
# 0                    CustomerID    int64     0     0.00    5630
# 1                         Churn    int64     0     0.00       2
# 2                        Tenure  float64   264     4.69      36
# 3          PreferredLoginDevice   object     0     0.00       3
# 4                      CityTier    int64     0     0.00       3
# 5               WarehouseToHome  float64   251     4.46      34
# 6          PreferredPaymentMode   object     0     0.00       7
# 7                        Gender   object     0     0.00       2
# 8                HourSpendOnApp  float64   255     4.53       6
# 9      NumberOfDeviceRegistered    int64     0     0.00       6
# 10             PreferedOrderCat   object     0     0.00       6
# 11            SatisfactionScore    int64     0     0.00       5
# 12                MaritalStatus   object     0     0.00       3
# 13              NumberOfAddress    int64     0     0.00      15
# ...

# %%
# Check duplicated data

Duplicated = df.duplicated().sum()
DuplicatedPerc = round((df.duplicated().sum()/df.shape[0])*100,2)
print(f'Jumlah Data Duplikat: {Duplicated}\nPersentase Data Duplikat: {DuplicatedPerc}%')
print(f'Jumlah baris dan kolom: {df.shape}')
# Out:
# Jumlah Data Duplikat: 0
# Persentase Data Duplikat: 0.0%
# Jumlah baris dan kolom: (5630, 20)

# %%
# Drop Kolom yang tidak digunakan
df.drop(['CustomerID'], axis=1, inplace=True)

# %% [markdown]
# Kolom CustomerID yang unik (tidak ada data yang sama) perlu di drop karena tidak akan digunakan untuk analisis

# %%
df[['Churn', 'DaySinceLastOrder']][df['Churn']==1]
# Out:
#       Churn  DaySinceLastOrder
# 0         1                5.0
# 1         1                0.0
# 2         1                3.0
# 3         1                3.0
# 4         1                3.0
# ...     ...                ...
# 5598      1                1.0
# 5602      1                3.0
# 5604      1                9.0
# 5612      1                2.0
# 5621      1                1.0
#
# [948 rows x 2 columns]

# %%
df.drop(['DaySinceLastOrder'], axis=1, inplace=True)

# %% [markdown]
# Berdasarkan Business Knowledge dan tabel sebelum ini, terlihat bahwa terjadi churn dengan terakhir order 0 hari. Sehingga Kolom DaySinceLastOrder didrop

# %% [markdown]
# Berikutnya akan dilihat masing-masing unique value dari variabel kategorikal dan numerikal

# %%
# Check typo for categorical column
cat_columns = df.select_dtypes(exclude=np.number).columns

for i in cat_columns:
    uniqueValue = df[i].unique()
    print(f"Feature {i}: {uniqueValue}")
# Out:
# Feature PreferredLoginDevice: ['Mobile Phone' 'Phone' 'Computer']
# Feature PreferredPaymentMode: ['Debit Card' 'UPI' 'CC' 'Cash on Delivery' 'E wallet' 'COD' 'Credit Card']
# Feature Gender: ['Female' 'Male']
# Feature PreferedOrderCat: ['Laptop & Accessory' 'Mobile' 'Mobile Phone' 'Others' 'Fashion' 'Grocery']
# Feature MaritalStatus: ['Single' 'Divorced' 'Married']

# %%
# Check typo for numerical column
num_columns = df.select_dtypes(include=np.number).columns

for i in num_columns:
    uniqueValue = df[i].unique()
    print(f"Feature {i}: {uniqueValue}")
# Out:
# Feature Churn: [1 0]
# Feature Tenure: [ 4. nan  0. 13. 11.  9. 19. 20. 14.  8. 18.  5.  2. 30.  1. 23.  3. 29.
#   6. 26. 28.  7. 24. 25. 10. 15. 22. 27. 16. 12. 21. 17. 50. 60. 31. 51.
#  61.]
# Feature CityTier: [3 1 2]
# Feature WarehouseToHome: [  6.   8.  30.  15.  12.  22.  11.   9.  31.  18.  13.  20.  29.  28.
#   26.  14.  nan  10.  27.  17.  23.  33.  19.  35.  24.  16.  25.  32.
#   34.   5.  21. 126.   7.  36. 127.]
# Feature HourSpendOnApp: [ 3.  2. nan  1.  0.  4.  5.]
# Feature NumberOfDeviceRegistered: [3 4 5 2 1 6]
# Feature SatisfactionScore: [2 3 5 4 1]
# Feature NumberOfAddress: [ 9  7  6  8  3  2  4 10  1  5 19 21 11 20 22]
# Feature Complain: [1 0]
# Feature OrderAmountHikeFromlastYear: [11. 15. 14. 23. 22. 16. 12. nan 13. 17. 18. 24. 19. 20. 21. 25. 26.]
# Feature CouponUsed: [ 1.  0.  4.  2.  9.  6. 11. nan  7. 12. 10.  5.  3. 13. 15.  8. 14. 16.]
# Feature OrderCount: [ 1.  6.  2. 15.  4.  7.  3.  9. nan 11.  5. 12. 10.  8. 13. 14. 16.]
# ...

# %% [markdown]
# Terdapat unique value yang masih rancu pada 'PreferredLoginDevice', 'PreferredPaymentMode', 'PreferedOrderCat', sehingga perlu diganti namanya agar menjadi lebih jelas

# %%
# Rename LoginDevice, PaymentMode, OrderCat, MaritalStatus
df['PreferredLoginDevice'] = df['PreferredLoginDevice'].replace({'Phone': 'Mobile Phone'})
df['PreferredPaymentMode'] = df['PreferredPaymentMode'].replace({'CC': 'Credit Card', 'COD': 'Cash on Delivery', 'UPI': 'Virtual Account'})
df['PreferedOrderCat'] = df['PreferedOrderCat'].replace({'Mobile': 'Electronic', 'Mobile Phone': 'Electronic', 'Laptop & Accessory': 'Electronic'})

# %%
# Check typo for categorical column
for i in cat_columns:
    uniqueValue = df[i].unique()
    print(f"Feature {i}: {uniqueValue}")
# Out:
# Feature PreferredLoginDevice: ['Mobile Phone' 'Computer']
# Feature PreferredPaymentMode: ['Debit Card' 'Virtual Account' 'Credit Card' 'Cash on Delivery'
#  'E wallet']
# Feature Gender: ['Female' 'Male']
# Feature PreferedOrderCat: ['Electronic' 'Others' 'Fashion' 'Grocery']
# Feature MaritalStatus: ['Single' 'Divorced' 'Married']

# %%
# Cek Missing Value
df.isna().sum()
# Out:
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# CashbackAmount                   0
# dtype: int64

# %%
def find_missing_values(df):
    result = []
    for i in df.columns:
        if df[i].isna().any():
            result.append((i, df[i].isna().sum() / df.shape[0] * 100))
    return result

missing_values_df = pd.DataFrame(find_missing_values(df), columns=["Features", "MissingPercentage"])
print(missing_values_df)
# Out:
#                       Features  MissingPercentage
# 0                       Tenure           4.689165
# 1              WarehouseToHome           4.458259
# 2               HourSpendOnApp           4.529307
# 3  OrderAmountHikeFromlastYear           4.706927
# 4                   CouponUsed           4.547069
# 5                   OrderCount           4.582593

# %%
missingno.matrix(df)
# Out:
# <Axes: >

# %%
missingno.bar(df,color="dodgerblue", sort="ascending", figsize=(10,5), fontsize=12);

# %% [markdown]
# Terlihat bahwa 6 dari 18 variabel memiliki missing value sehingga perlu dihandle seperti berikut.

# %%
missingvalue = df[df.isna().sum()[df.isna().sum() > 0].index]
missingvalue
# Out:
#       Tenure  WarehouseToHome  HourSpendOnApp  OrderAmountHikeFromlastYear  \
# 0        4.0              6.0             3.0                         11.0
# 1        NaN              8.0             3.0                         15.0
# 2        NaN             30.0             2.0                         14.0
# 3        0.0             15.0             2.0                         23.0
# 4        0.0             12.0             NaN                         11.0
# ...      ...              ...             ...                          ...
# 5625    10.0             30.0             3.0                         18.0
# 5626    13.0             13.0             3.0                         16.0
# 5627     1.0             11.0             3.0                         21.0
# 5628    23.0              9.0             4.0                         15.0
# 5629     8.0             15.0             3.0                         13.0
#
#       CouponUsed  OrderCount
# 0            1.0         1.0
# ...

# %%
missing_columns = df.columns[df.isna().sum() > 0]

fig = plt.figure(figsize=(12, 18))

for i, col in enumerate(missing_columns):
    fig.add_subplot(9, 4, i+1)
    sns.kdeplot(df[col], shade=True)

plt.tight_layout()
plt.show()

# %%
# Tenure
df['Tenure'] = df['Tenure'].fillna(df['Tenure'].median())
df['Tenure'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Sejak data Tenure bertipe kontinu dan memiliki distribusi tidak merata, Data tersebut menggunakan imputasi median

# %%
# WarehouseToHome
df['WarehouseToHome'] = df['WarehouseToHome'].fillna(df['Tenure'].median())
df['WarehouseToHome'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Sejak data WarehouseToHome bertipe kontinu dan memiliki distribusi tidak merata, Data tersebut menggunakan imputasi median

# %%
# HourSpendOnApp
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan , strategy = 'most_frequent')
df['HourSpendOnApp'] = imputer.fit_transform(pd.DataFrame(df['HourSpendOnApp']))
df['HourSpendOnApp'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Sejak data HourSpendOnApp bertipe diskrit dan memiliki pola distribusi yang mudah diidentifikasi (cenderung di nilai 2, 3, 4), Data tersebut menggunakan imputasi mode/modus

# %%
# OrderAmountHikeFromlastYear
df['OrderAmountHikeFromlastYear'] = df['OrderAmountHikeFromlastYear'].fillna(df['OrderAmountHikeFromlastYear'].median())
df['OrderAmountHikeFromlastYear'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Sejak data OrderAmountHikeFromlastYear bertipe kontinu dan memiliki distribusi skewed positif, Data tersebut menggunakan imputasi median

# %%
# CouponUsed
df['CouponUsed']=imputer.fit_transform(df[['CouponUsed']])
df['CouponUsed'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Sejak data CouponUsed bertipe diskrit, Data tersebut menggunakan imputasi mode/modus. Biasanya, jumlah kupon yang digunakan memiliki pola distribusi yang mudah diidentifikasi.

# %%
# OrderCount
df['OrderCount']=imputer.fit_transform(df[['OrderCount']])
df['OrderCount'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Sejak data OrderCount bertipe diskrit dan  jumlah pesanan cenderung mirip antara pelanggan, Data tersebut menggunakan imputasi mode/modus.

# %%
fig = plt.figure(figsize=(12, 18))

for i, col in enumerate(missingvalue):
    fig.add_subplot(9, 4, i+1)
    sns.kdeplot(df[col], shade=True)

plt.tight_layout()
plt.show()

# %%
df.isnull().sum()
# Out:
# Churn                          0
# Tenure                         0
# PreferredLoginDevice           0
# CityTier                       0
# WarehouseToHome                0
# PreferredPaymentMode           0
# Gender                         0
# HourSpendOnApp                 0
# NumberOfDeviceRegistered       0
# PreferedOrderCat               0
# SatisfactionScore              0
# MaritalStatus                  0
# NumberOfAddress                0
# Complain                       0
# OrderAmountHikeFromlastYear    0
# CouponUsed                     0
# OrderCount                     0
# CashbackAmount                 0
# dtype: int64

# %% [markdown]
# Sejak missing value sudah terisi semua, dilakukan pengecekan outlier dan handling outlier seperti berikut.

# %%
# Cek Outlier
# Display boxplot before outliers handling
columns_to_plot = df.select_dtypes(exclude=['object']).columns
plt.figure(figsize=(18, 20))

for i, col in enumerate(columns_to_plot, 1):
    plt.subplot((len(columns_to_plot) // 3 + 1), 3, i)
    sns.boxplot(data=df, y=col)
    plt.title(f'Boxplot Kolom: {col}')

plt.tight_layout()
plt.show()

# %%
print(f"Data sebelum handle outlier: {df.shape}")
# Out:
# Data sebelum handle outlier: (5630, 18)

# %%
from scipy.stats import zscore

# Mendapatkan hanya kolom numerik dari dataframe
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Menghitung Z-score untuk setiap kolom numerik
z_scores = df[numeric_columns].apply(zscore, nan_policy='omit')

# Identifikasi outliers: Data dengan Z-score di atas 3 atau di bawah -3 dianggap sebagai outliers
outliers = (z_scores > 3) | (z_scores < -3)

# Mengatasi outliers dengan cara membuang baris yang memiliki outliers
df = df[(z_scores < 3).all(axis=1) & (z_scores > -3).all(axis=1)]

# Menampilkan hasil dari dataframe yang sudah diatasi outliersnya
df.shape
# Out:
# (5376, 18)

# %% [markdown]
# Dengan menggunakan Z-score, data terbaru memiliki jumlah baris 5376. Berkurang sekitar 254 data

# %% [markdown]
# Z-score cocok digunakan pada dataset ini karena dataset tersebut memiliki banyak kolom numerik yang memiliki distribusi kontinyu, yang dapat diukur secara kuantitatif menggunakan Z-score.
#
# Metode ini memungkinkan identifikasi outliers yang jelas pada kolom yang mungkin memiliki distribusi skewed atau long-tailed seperti Tenure dan WarehouseToHome.
#
# Selain itu, Z-score memberikan pendekatan yang efisien dan konsisten dalam mengatasi outliers, terutama dalam skenario di mana data dengan distribusi hampir normal atau kontinyu perlu dianalisis tanpa kehilangan banyak data.

# %%
# Display boxplot after outliers handling
plt.figure(figsize=(18, 20))

for i, col in enumerate(numeric_columns, 1):
    plt.subplot((len(numeric_columns) // 3 + 1), 3, i)
    sns.boxplot(data=df, y=col)
    plt.title(f'Boxplot Kolom: {col} (After Outlier Handling)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Setelah datanya sudah bersih, dilanjutkan dengan tahap Analisa Data.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
import plotly.express as px

churn_counts = df['Churn'].value_counts()
labels = ['Still Using', 'Stop Using']
colors = ['blue', 'red']

fig = px.pie(names=labels, values=churn_counts, title='Churn Distribution',
             labels={'names': 'Churn', 'values': 'Count'},
             color_discrete_sequence=colors,
             hover_name=labels,
             hole=0.4)

fig.update_traces(textinfo='percent+label')

fig.update_layout(title_text='Churn Distribution', title_x=0.5, title_y=0.9, title_font_size=20)

fig.show()

# %% [markdown]
# Data menunjukkan bahwa mayoritas pelanggan (83%) tidak berhenti berlangganan, sedangkan persentase kecil (17%) berhenti berlangganan.
#
# Meskipun churn rate relatif rendah, tetap masih ada ruangan untuk perbaikan. Kami akan menganalisis faktor kontribusi untuk pelanggan berhenti berlangganan dan merancang strategi untuk mengurangi rate tersebut.

# %%
# convert num_cols to categories
df2 = df.copy()
for col in df2.columns:
  if col == 'CustomerID':
    continue

  else:
    if df2[col].dtype == 'int':
      df2[col] = df[col].astype(str)

df2.dtypes
# Out:
# Churn                            int64
# Tenure                         float64
# PreferredLoginDevice            object
# CityTier                         int64
# WarehouseToHome                float64
# PreferredPaymentMode            object
# Gender                          object
# HourSpendOnApp                 float64
# NumberOfDeviceRegistered         int64
# PreferedOrderCat                object
# SatisfactionScore                int64
# MaritalStatus                   object
# NumberOfAddress                  int64
# Complain                         int64
# OrderAmountHikeFromlastYear    float64
# CouponUsed                     float64
# OrderCount                     float64
# CashbackAmount                 float64
# dtype: object

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
binary_cat_cols = ['Complain']
outcome = ['Churn']
cat_cols = ['PreferredLoginDevice', 'CityTier', 'PreferredPaymentMode',
       'Gender', 'NumberOfDeviceRegistered', 'PreferedOrderCat',
       'SatisfactionScore', 'MaritalStatus', 'NumberOfAddress', 'Complain']
num_cols = ['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'CashbackAmount']

# %% [markdown]
# Mari kita lihat persebaran distribusi dari Variabel Kategorikal dan Numerikal.

# %% [markdown]
# ### Churn Dynamics - Kategorikal

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Menghitung jumlah nilai untuk masing-masing kategori berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = df2.groupby(['PreferredLoginDevice', 'Churn']).size().reset_index(name='count')

# Menghitung total count per 'PreferredLoginDevice'
totals = counts.groupby('PreferredLoginDevice')['count'].sum().reset_index(name='total_count')

# Menggabungkan counts dengan total count
counts = pd.merge(counts, totals, on='PreferredLoginDevice', suffixes=('', '_total'))

# Menghitung persentase
counts['percentage'] = (counts['count'] / counts['total_count']) * 100

# Sorting data berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = counts.sort_values(by=['PreferredLoginDevice', 'Churn'], ascending=[True, False])

# Membuat dataframe dengan count_data untuk plot bertumpuk
count_data = counts.pivot(index='PreferredLoginDevice', columns='Churn', values='count').fillna(0)

# Membuat plot bertumpuk
ax = count_data.plot(kind='barh', stacked=True, color=['blue', 'red'], figsize=(12, 8))

# Menambahkan judul dan label
plt.title('Distribution of PreferredLoginDevice by Churn', fontsize=20)
plt.xlabel('Count')
plt.ylabel('Preferred Login Device')

# Menambahkan persentase sebagai teks pada batang
# Menghitung persentase untuk masing-masing stack (Churn dan Non-Churn)
for i, container in enumerate(ax.containers):
    if container:
        if i == 0:  # Non-Churn (color blue)
            labels = counts[counts['Churn'] == 0]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()
        else:  # Churn (color red)
            labels = counts[counts['Churn'] == 1]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()

        # Menambahkan label pada plot
        ax.bar_label(container, labels=labels, label_type='center')

# Menambahkan legenda
plt.legend(title='Churn', loc='upper right')

# Mengatur tata letak
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan grafik tersebut, terlihat bahwa preferensi perangkat login para pelanggan sebagian besar menggunakan Mobile Phone dibandingkan dengan Computer, dengan tingkat churn yang lebih tinggi pada pengguna Mobile Phone.
# Rekomendasi:
#
# 1. Peningkatan Tampilan Versi Computer: Membuat UI yang lebih ramah pengguna (user-friendly) untuk versi Computer guna meningkatkan jumlah pelanggan. Hal ini dapat dilakukan dengan A/B testing, dengan melakukan sampling pada dua atau lebih varian UI untuk menentukan mana yang lebih disukai atau mendapatkan feedback terbaik dari pengguna.
# - Pros: Merupakan investasi jangka panjang yang dapat meningkatkan kepuasan dan retensi pengguna di perangkat komputer.
# - Cons: Membutuhkan waktu, tenaga kerja, dan sumber daya manusia untuk desain, pengembangan, dan analisis hasil.
# - Tambahan: Pertimbangkan untuk fokus pada elemen UI yang paling memengaruhi pengalaman pengguna, seperti navigasi yang mudah, visual yang menarik, dan kecepatan akses.
# 2. Strategi untuk Pengguna Mobile Phone: Menawarkan bonus seperti free ongkir kepada pelanggan untuk mengurangi churn, dengan ketentuan tersedia maksimal 3 kali dalam sebulan dan maksimal free ongkir 15.000 seperti pada Shopee, Tokopedia, dll. Strategi ini bertujuan untuk meningkatkan retensi pengguna pada perangkat mobile dengan memberikan insentif yang langsung terasa manfaatnya.
# - Pros: Lebih murah dan cepat untuk diimplementasikan dibandingkan perubahan UI, dengan potensi hasil yang langsung terlihat dalam jangka pendek.
# - Cons: Membawa biaya langsung yang segera berdampak pada keuntungan dan berisiko menciptakan persepsi bahwa produk lebih bernilai ketika ada potongan harga, yang dapat merusak persepsi nilai produk dalam jangka panjang.
# - Tambahan: Selain bonus free ongkir, pertimbangkan program loyalitas atau reward yang dapat diakumulasi untuk meningkatkan engagement tanpa harus selalu mengorbankan margin keuntungan. Selain itu, evaluasi dampak program ini secara berkala untuk memastikan bahwa strategi tersebut efektif dalam menurunkan churn.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Menghitung jumlah nilai untuk masing-masing kategori berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = df2.groupby(['PreferredPaymentMode', 'Churn']).size().reset_index(name='count')

# Menghitung total count per 'PreferredLoginDevice'
totals = counts.groupby('PreferredPaymentMode')['count'].sum().reset_index(name='total_count')

# Menggabungkan counts dengan total count
counts = pd.merge(counts, totals, on='PreferredPaymentMode', suffixes=('', '_total'))

# Menghitung persentase
counts['percentage'] = (counts['count'] / counts['total_count']) * 100

# Sorting data berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = counts.sort_values(by=['PreferredPaymentMode', 'Churn'], ascending=[True, False])

# Membuat dataframe dengan count_data untuk plot bertumpuk
count_data = counts.pivot(index='PreferredPaymentMode', columns='Churn', values='count').fillna(0)

# Membuat plot bertumpuk
ax = count_data.plot(kind='barh', stacked=True, color=['blue', 'red'], figsize=(12, 8))

# Menambahkan judul dan label
plt.title('Distribution of PreferredPaymentMode by Churn', fontsize=20)
plt.xlabel('Count')
plt.ylabel('Preferred Payment Mode')

# Menambahkan persentase sebagai teks pada batang
# Menghitung persentase untuk masing-masing stack (Churn dan Non-Churn)
for i, container in enumerate(ax.containers):
    if container:
        if i == 0:  # Non-Churn (color blue)
            labels = counts[counts['Churn'] == 0]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()
        else:  # Churn (color red)
            labels = counts[counts['Churn'] == 1]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()

        # Menambahkan label pada plot
        ax.bar_label(container, labels=labels, label_type='center')

# Menambahkan legenda
plt.legend(title='Churn', loc='upper right')

# Mengatur tata letak
plt.tight_layout()
plt.show()

# %% [markdown]
# Analisa churn based on payment option:
#
# Jumlah Churn tertinggi berada pada Debit Card dan Credit Card: Untuk perbaikan kinerja pada payment option tersebut dapat di tambahkan opsi yang lebih fleksibel dan beragam pada pilihan rekanan jaringan kartu bisa mencakup Visa, Master Card, Link, ATM bersama maupun jaringan lainnnya. Untuk meyakinkan keamanan penggunaan kartu dari platform bisa meningkatkan keamanan seperti adanya notifikasi payment pada buyer serta mekanisme otentifikasi yang lebih robust.
#
# Alpha e-commerce saat ini sedang berupaya menjalin kerja sama dengan bank-bank besar yang memiliki basis pengguna yang luas, seperti BCA, Mandiri, BNI, dan BRI. Kerja sama ini bertujuan untuk memperoleh insentif yang dapat digunakan sebagai cashback bagi pelanggan yang melakukan transaksi menggunakan bank-bank tersebut.
#
# Menyediakan sistem pembayaran Cash on Delivery (COD) dengan tambahan biaya layanan bagi produk yang memerlukan bongkar/pasang dapat menjadi solusi bagi pelanggan yang kurang nyaman menggunakan kartu. Ini juga memberikan fleksibilitas lebih tanpa mengurangi layanan yang tersedia.
#
# Pada sisi lain apabila dihitung berdasarkan persentase Churn pada setiap payment option dapat diketahui yang tertinggi (diatas 20%) adalah COD (25%) dan E wallet (24%). Kendala COD biasanya pada payment saat barang datang, antara kesesuaian waktu kurir dan cara pembayaran cash. Performa COD bisa ditingkatkan dengan adanya mekanisme nitifikasi/konfirmasi dari kurir kapan buyer ada di rumah dan prefer di kirim. Atau di tambahkan juga fitur pemilihan waktu pengiriman yang preferrable bagi buyer pada platform pada saat pemesanan. Selain itu untuk mempermudah pembayaran buyer, kurir juga membawa media transaksi yang beragam seperti EDC maupun media lainnya yang bisa menampilkan QR payment. Untuk E-Wallet agar ditambahkan juga variasi atau ragam kerjasama perusahaan degan e-wallet yang ada di pasar.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Menghitung jumlah nilai untuk masing-masing kategori berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = df2.groupby(['Gender', 'Churn']).size().reset_index(name='count')

# Menghitung total count per 'PreferredLoginDevice'
totals = counts.groupby('Gender')['count'].sum().reset_index(name='total_count')

# Menggabungkan counts dengan total count
counts = pd.merge(counts, totals, on='Gender', suffixes=('', '_total'))

# Menghitung persentase
counts['percentage'] = (counts['count'] / counts['total_count']) * 100

# Sorting data berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = counts.sort_values(by=['Gender', 'Churn'], ascending=[True, False])

# Membuat dataframe dengan count_data untuk plot bertumpuk
count_data = counts.pivot(index='Gender', columns='Churn', values='count').fillna(0)

# Membuat plot bertumpuk
ax = count_data.plot(kind='barh', stacked=True, color=['blue', 'red'], figsize=(12, 8))

# Menambahkan judul dan label
plt.title('Distribution of Gender by Churn', fontsize=20)
plt.xlabel('Count')
plt.ylabel('Gender')

# Menambahkan persentase sebagai teks pada batang
# Menghitung persentase untuk masing-masing stack (Churn dan Non-Churn)
for i, container in enumerate(ax.containers):
    if container:
        if i == 0:  # Non-Churn (color blue)
            labels = counts[counts['Churn'] == 0]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()
        else:  # Churn (color red)
            labels = counts[counts['Churn'] == 1]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()

        # Menambahkan label pada plot
        ax.bar_label(container, labels=labels, label_type='center')

# Menambahkan legenda
plt.legend(title='Churn', loc='upper right')

# Mengatur tata letak
plt.tight_layout()
plt.show()

# %% [markdown]
# Secara jumlah, customer Laki-laki lebih banyak yang churn apabila dibandingkan dengan perempuan namun secara persentase tidak terlalu jauh perbedaannya dimana laki-laki adalah 18% dan wanita adalah 16%. Dapat dievaluasi juga pemerataan produk yang lebih variatif untuk kedua gender.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Menghitung jumlah nilai untuk masing-masing kategori berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = df2.groupby(['PreferedOrderCat', 'Churn']).size().reset_index(name='count')

# Menghitung total count per 'PreferredLoginDevice'
totals = counts.groupby('PreferedOrderCat')['count'].sum().reset_index(name='total_count')

# Menggabungkan counts dengan total count
counts = pd.merge(counts, totals, on='PreferedOrderCat', suffixes=('', '_total'))

# Menghitung persentase
counts['percentage'] = (counts['count'] / counts['total_count']) * 100

# Sorting data berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = counts.sort_values(by=['PreferedOrderCat', 'Churn'], ascending=[True, False])

# Membuat dataframe dengan count_data untuk plot bertumpuk
count_data = counts.pivot(index='PreferedOrderCat', columns='Churn', values='count').fillna(0)

# Membuat plot bertumpuk
ax = count_data.plot(kind='bar', stacked=True, color=['blue', 'red'], figsize=(12, 8))

# Menambahkan judul dan label
plt.title('Distribution of PreferedOrderCat by Churn', fontsize=20)
plt.xlabel('Count')
plt.ylabel('PreferedOrderCat')

# Menambahkan persentase sebagai teks pada batang
# Menghitung persentase untuk masing-masing stack (Churn dan Non-Churn)
for i, container in enumerate(ax.containers):
    if container:
        if i == 0:  # Non-Churn (color blue)
            labels = counts[counts['Churn'] == 0]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()
        else:  # Churn (color red)
            labels = counts[counts['Churn'] == 1]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()

        # Menambahkan label pada plot
        ax.bar_label(container, labels=labels, label_type='center')

# Menambahkan legenda
plt.legend(title='Churn', loc='upper right')

# Mengatur tata letak
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan grafik tersebut, Terlihat bahwa pembeliatn category Electronic menduduki peringkat pertama, diikuti dengan category fashion dan grocery di peringkat 2 dan 3. Rekomendasi:
# 1. Untuk kategori elektronik, Alpha e-commerce memberikan insentif berupa free ongkir untuk transaksi di atas 100 ribu, serta tambahan asuransi dan cashback 10% untuk pembelian dengan nilai transaksi di atas 1 juta. Langkah ini bertujuan untuk mendorong pelanggan melakukan pembelian dengan nilai yang lebih tinggi serta meningkatkan rasa aman saat bertransaksi barang elektronik. Kerja sama dengan penyedia asuransi, seperti Tokio Marine, Zurich, dan lainnya, juga diupayakan agar kedua belah pihak dapat saling menguntungkan, meningkatkan kepercayaan pelanggan, dan memperkuat posisi Alpha e-commerce di pasar.
#
# - Pros:
# Meningkatkan nilai rata-rata transaksi (average order value) dan mendorong pembelian dengan nominal lebih tinggi, Memberikan rasa aman dengan asuransi yang dapat mengurangi risiko bagi pelanggan, Cashback meningkatkan loyalitas dan mendorong pembelian berulang.
# - Cons:
# Biaya operasional meningkat karena pemberian free ongkir dan asuransi,
# Cashback berpotensi mengurangi margin keuntungan terutama jika digunakan secara berulang oleh pelanggan.
# 2. Untuk Kategori Fashion: Terapkan diskon hingga 50% dengan jangka waktu terbatas, misalnya diskon hingga 50% pada jam tertentu, seperti dari jam 10.00-11.00. Strategi ini bertujuan untuk menciptakan urgensi dan memicu perilaku impulsif pelanggan, sehingga mereka lebih terdorong untuk bertransaksi tanpa berpikir terlalu lama.
#
# - Pros:
# Memicu peningkatan penjualan dalam jangka pendek melalui pembelian impulsif, Meningkatkan traffic selama periode diskon yang mana berpotensi meningkatkan penjualan kategori lain, Membantu dalam menyingkirkan stok lama atau produk dengan perputaran yang lambat.
# - Cons:
# Diskon berlebihan dapat mengurangi persepsi nilai produk dan membiasakan pelanggan hanya berbelanja saat ada diskon, Potensi churn bisa meningkat setelah diskon berakhir jika pelanggan merasa nilai produk kurang menarik tanpa diskon.
# 3. Untuk Kategori Grocery: Tetapkan margin keuntungan serendah mungkin dan rekrut influencer dengan gaya hidup sehat sebagai Brand Ambassador untuk menarik pelanggan sebanyak-banyaknya. Kategori ini memiliki churn yang rendah, sehingga strategi ini bertujuan untuk memperbesar pangsa pasar dengan volume penjualan tinggi tanpa mengkhawatirkan churn.
#
# - Pros:
# Meningkatkan awareness dan daya tarik produk melalui endorsement oleh influencer yang relevan dengan gaya hidup sehat, Memanfaatkan churn yang rendah untuk mendorong volume penjualan yang tinggi yang dapat mengkompensasi margin yang tipis, Menarik pelanggan baru melalui kampanye pemasaran yang autentik dan terhubung langsung dengan target pasar.
# - Cons:
# Biaya pemasaran untuk hiring influencer dan kegiatan promosi bisa cukup tinggi, ketergantungan yang besar pada volume penjualan yang tinggi untuk mencapai profitabilitas.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Menghitung jumlah nilai untuk masing-masing kategori berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = df2.groupby(['MaritalStatus', 'Churn']).size().reset_index(name='count')

# Menghitung total count per 'PreferredLoginDevice'
totals = counts.groupby('MaritalStatus')['count'].sum().reset_index(name='total_count')

# Menggabungkan counts dengan total count
counts = pd.merge(counts, totals, on='MaritalStatus', suffixes=('', '_total'))

# Menghitung persentase
counts['percentage'] = (counts['count'] / counts['total_count']) * 100

# Sorting data berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = counts.sort_values(by=['MaritalStatus', 'Churn'], ascending=[True, False])

# Membuat dataframe dengan count_data untuk plot bertumpuk
count_data = counts.pivot(index='MaritalStatus', columns='Churn', values='count').fillna(0)

# Membuat plot bertumpuk
ax = count_data.plot(kind='barh', stacked=True, color=['blue', 'red'], figsize=(12, 8))

# Menambahkan judul dan label
plt.title('Distribution of MaritalStatus by Churn', fontsize=20)
plt.xlabel('Count')
plt.ylabel('Marital Status')

# Menambahkan persentase sebagai teks pada batang
# Menghitung persentase untuk masing-masing stack (Churn dan Non-Churn)
for i, container in enumerate(ax.containers):
    if container:
        if i == 0:  # Non-Churn (color blue)
            labels = counts[counts['Churn'] == 0]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()
        else:  # Churn (color red)
            labels = counts[counts['Churn'] == 1]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()

        # Menambahkan label pada plot
        ax.bar_label(container, labels=labels, label_type='center')

# Menambahkan legenda
plt.legend(title='Churn', loc='upper right')

# Mengatur tata letak
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan grafik, terlihat bahwa transaksi terbanyak dilakukan oleh pelanggan berstatus Married, diikuti oleh pelanggan berstatus Single. Namun, churn tertinggi terdapat pada pelanggan yang berstatus Single, menunjukkan bahwa kelompok ini lebih rentan untuk berhenti menggunakan layanan. Oleh karena itu, rekomendasi yang disesuaikan untuk masing-masing segmen pelanggan sangat penting untuk menurunkan churn dan meningkatkan loyalitas. Rekomendasi:
# 1. Untuk yang berstatus Single: Berikan insentif berupa free ongkir untuk transaksi di atas 30 ribu dan cashback 5% yang berlaku dalam jangka waktu tertentu. Strategi ini bertujuan untuk menarik dan mempertahankan pelanggan single, yang cenderung sensitif terhadap biaya tambahan seperti ongkos kirim.
#
# - Pros:
#
# Meningkatkan frekuensi transaksi dengan insentif langsung yang dirasakan pelanggan.
# Mendorong pembelian berulang dalam jangka pendek dengan cashback, yang dapat meningkatkan retensi.
# Menurunkan churn dengan menambahkan nilai lebih pada setiap transaksi yang mereka lakukan.
# - Cons:
#
# Memberikan free ongkir dan cashback dapat mengurangi margin keuntungan, terutama jika tidak diimbangi dengan peningkatan volume penjualan yang signifikan.
# Potensi terbentuknya persepsi bahwa produk atau layanan hanya bernilai ketika ada insentif, yang dapat merusak loyalitas jangka panjang jika insentif dihentikan.
# 2. Untuk yang berstatus Married: Berikan insentif berupa free ongkir untuk transaksi di atas 100 ribu dan tawarkan bundling diskon harga. Pendekatan ini sesuai dengan pola belanja pelanggan married yang cenderung melakukan transaksi dengan nilai lebih tinggi dan lebih tertarik pada pembelian paket atau bundling yang memberikan nilai lebih.
#
# - Pros:
#
# Meningkatkan nilai rata-rata transaksi (average order value) dengan mendorong pelanggan untuk melakukan pembelian yang lebih besar.
# Bundling diskon dapat mempercepat penjualan produk tertentu dan mengurangi stok barang dengan cepat.
# Menjaga loyalitas pelanggan married yang cenderung stabil dalam perilaku belanja dengan memberikan penawaran yang sesuai dengan kebutuhan mereka.
# - Cons:
#
# Membatasi free ongkir pada transaksi dengan nominal tinggi dapat membatasi efektivitas insentif bagi pelanggan yang biasanya melakukan transaksi dengan nilai lebih rendah.
# Diskon bundling dapat menekan margin keuntungan, terutama jika diskon yang diberikan terlalu besar atau jika pelanggan lebih tertarik pada produk diskon daripada produk reguler.

# %%
# Menghitung jumlah nilai untuk masing-masing kategori berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = df2.groupby(['CityTier', 'Churn']).size().reset_index(name='count')

# Menghitung total count per 'PreferredLoginDevice'
totals = counts.groupby('CityTier')['count'].sum().reset_index(name='total_count')

# Menggabungkan counts dengan total count
counts = pd.merge(counts, totals, on='CityTier', suffixes=('', '_total'))

# Menghitung persentase
counts['percentage'] = (counts['count'] / counts['total_count']) * 100

# Sorting data berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = counts.sort_values(by=['CityTier', 'Churn'], ascending=[True, False])

# Membuat dataframe dengan count_data untuk plot bertumpuk
count_data = counts.pivot(index='CityTier', columns='Churn', values='count').fillna(0)

# Membuat plot bertumpuk
ax = count_data.plot(kind='bar', stacked=False, color=['blue', 'red'], figsize=(12, 8))

# Menambahkan judul dan label
plt.title('Distribution of CityTier by Churn', fontsize=20)
plt.xlabel('Count')
plt.ylabel('City Tier')

# Menambahkan persentase sebagai teks pada batang
# Menghitung persentase untuk masing-masing stack (Churn dan Non-Churn)
for i, container in enumerate(ax.containers):
    if container:
        if i == 0:  # Non-Churn (color blue)
            labels = counts[counts['Churn'] == 0]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()
        else:  # Churn (color red)
            labels = counts[counts['Churn'] == 1]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()

        # Menambahkan label pada plot
        ax.bar_label(container, labels=labels, label_type='center')

# Menambahkan legenda
plt.legend(title='Churn', loc='upper right')

# Mengatur tata letak
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan grafik di atas tier kota dengan persentase tingkat churn tertinggi berada pada tier 2 dan tier 3 dengan indikasi merupakan kota rural dan remote. Untuk itu perbaikan rasio churn bisa dilakukan dengan memberikan diskon atau potongan ongkir  bagi rural atau remote area pada kuantitas tertentu yang secara economic of scale masih menguntungkan bagi perusahaan. Misalkan potongan ongkir diatas order 100 ribu.

# %%
# Menghitung jumlah nilai untuk masing-masing kategori berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = df2.groupby(['SatisfactionScore', 'Churn']).size().reset_index(name='count')

# Menghitung total count per 'PreferredLoginDevice'
totals = counts.groupby('SatisfactionScore')['count'].sum().reset_index(name='total_count')

# Menggabungkan counts dengan total count
counts = pd.merge(counts, totals, on='SatisfactionScore', suffixes=('', '_total'))

# Menghitung persentase
counts['percentage'] = (counts['count'] / counts['total_count']) * 100

# Sorting data berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = counts.sort_values(by=['SatisfactionScore', 'Churn'], ascending=[True, False])

# Membuat dataframe dengan count_data untuk plot bertumpuk
count_data = counts.pivot(index='SatisfactionScore', columns='Churn', values='count').fillna(0)

# Membuat plot bertumpuk
ax = count_data.plot(kind='bar', stacked=False, color=['blue', 'red'], figsize=(12, 8))

# Menambahkan judul dan label
plt.title('Distribution of SatisfactionScore by Churn', fontsize=20)
plt.xlabel('Count')
plt.ylabel('Satisfaction Score')

# Menambahkan persentase sebagai teks pada batang
# Menghitung persentase untuk masing-masing stack (Churn dan Non-Churn)
for i, container in enumerate(ax.containers):
    if container:
        if i == 0:  # Non-Churn (color blue)
            labels = counts[counts['Churn'] == 0]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()
        else:  # Churn (color red)
            labels = counts[counts['Churn'] == 1]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()

        # Menambahkan label pada plot
        ax.bar_label(container, labels=labels, label_type='center')

# Menambahkan legenda
plt.legend(title='Churn', loc='upper right')

# Mengatur tata letak
plt.tight_layout()
plt.show()

# %% [markdown]
# Jika dianalisa berdasarkan tingkat satisfaction ternyata tingkat kepuasan tidak monotonis dengan tingkat churn rate. tingkat kepuasan 5 memiliki tingkat churn yang lebih tinggi. Untuk memperbaiki hal tersebut hendaknya dibuat program yang bersifat menjaga retensi customer yang puas. Seperti adanya reward setelah pembelian mencapai kuantitas atau frekuensi tertentu. Adanya membership discount. Adanya leveling customer berdasarkan tingkat loyalitas pembelian dll.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5376 entries, 0 to 5629
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Churn                        5376 non-null   int64
#  1   Tenure                       5376 non-null   float64
#  2   PreferredLoginDevice         5376 non-null   object
#  3   CityTier                     5376 non-null   int64
#  4   WarehouseToHome              5376 non-null   float64
#  5   PreferredPaymentMode         5376 non-null   object
#  6   Gender                       5376 non-null   object
#  7   HourSpendOnApp               5376 non-null   float64
#  8   NumberOfDeviceRegistered     5376 non-null   int64
#  9   PreferedOrderCat             5376 non-null   object
#  10  SatisfactionScore            5376 non-null   int64
#  11  MaritalStatus                5376 non-null   object
#  12  NumberOfAddress              5376 non-null   int64
# ...

# %%
# Menghitung jumlah nilai untuk masing-masing kategori berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = df2.groupby(['Complain', 'Churn']).size().reset_index(name='count')

# Menghitung total count per 'PreferredLoginDevice'
totals = counts.groupby('Complain')['count'].sum().reset_index(name='total_count')

# Menggabungkan counts dengan total count
counts = pd.merge(counts, totals, on='Complain', suffixes=('', '_total'))

# Menghitung persentase
counts['percentage'] = (counts['count'] / counts['total_count']) * 100

# Sorting data berdasarkan 'PreferredLoginDevice' dan 'Churn'
counts = counts.sort_values(by=['Complain', 'Churn'], ascending=[True, False])

# Membuat dataframe dengan count_data untuk plot bertumpuk
count_data = counts.pivot(index='Complain', columns='Churn', values='count').fillna(0)

# Membuat plot bertumpuk
ax = count_data.plot(kind='bar', stacked=False, color=['blue', 'red'], figsize=(12, 8))

# Menambahkan judul dan label
plt.title('Distribution of Complain by Churn', fontsize=20)
plt.xlabel('Count')
plt.ylabel('Complain')

# Menambahkan persentase sebagai teks pada batang
# Menghitung persentase untuk masing-masing stack (Churn dan Non-Churn)
for i, container in enumerate(ax.containers):
    if container:
        if i == 0:  # Non-Churn (color blue)
            labels = counts[counts['Churn'] == 0]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()
        else:  # Churn (color red)
            labels = counts[counts['Churn'] == 1]['percentage'].apply(lambda x: f"{x:.2f}%").tolist()

        # Menambahkan label pada plot
        ax.bar_label(container, labels=labels, label_type='center')

# Menambahkan legenda
plt.legend(title='Churn', loc='upper right')

# Mengatur tata letak
plt.tight_layout()
plt.show()

# %% [markdown]
# Analisa berdasarkan jumlah customer yang komplain menunjukkan baik secara angka absolut maupun persetase, customer yang komplain cenderung akan churn (rasio churn customer yang komplain adalah 32%, tiga kali lipat dari customer yang tidak complain (hanya 11%). Dengan demikian complaint handling perlu ditingkatkan dan diberikan stimulus bagi customer yg complaint yang disebabkan atas kelalaian toko/seller. Misalkan diberikan discount/cashback atas produk sebagai kompensasi kelalaian seller atau diberikan gratis ongkir untuk pengembalian produk atau mekanisme klaim pengembalian produk yg lebih mudah (dijemput oleh kurir atau  dikirim baru untuk produk cacat)

# %% [markdown]
# ### Churn Dynamics - Numerical

# %%
# Plotting distribution plots for each variable with hue 'Churn'
fig, axes = plt.subplots(4, 2, figsize=(15, 20))
fig.suptitle('Distribution of Variables by Churn', fontsize=20)

sns.kdeplot(data=df2, x='Tenure', hue='Churn', multiple='stack', ax=axes[0, 0], palette='rainbow')
axes[0, 0].set_title('Tenure')

sns.kdeplot(data=df2, x='WarehouseToHome', hue='Churn', multiple='stack', ax=axes[0, 1], palette='rainbow')
axes[0, 1].set_title('WarehouseToHome')

sns.kdeplot(data=df2, x='HourSpendOnApp', hue='Churn', multiple='stack', ax=axes[1, 0], palette='rainbow')
axes[1, 0].set_title('HourSpendOnApp')

sns.kdeplot(data=df2, x='OrderAmountHikeFromlastYear', hue='Churn', multiple='stack', ax=axes[1, 1], palette='rainbow')
axes[1, 1].set_title('OrderAmountHikeFromlastYear')

sns.kdeplot(data=df2, x='CouponUsed', hue='Churn', multiple='stack', ax=axes[2, 0], palette='rainbow')
axes[2, 0].set_title('CouponUsed')

sns.kdeplot(data=df2, x='OrderCount', hue='Churn', multiple='stack', ax=axes[2, 1], palette='rainbow')
axes[2, 1].set_title('OrderCount')

sns.kdeplot(data=df2, x='CashbackAmount', hue='Churn', multiple='stack', ax=axes[3, 0], palette='rainbow')
axes[3, 0].set_title('CashbackAmount')

# Removing empty subplot
axes[3, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
# Creating boxplots for each variable
fig, axes = plt.subplots(4, 2, figsize=(15, 20))
fig.suptitle('Boxplots of Variables by Churn', fontsize=20)

sns.boxplot(data=df2, x='Churn', y='Tenure', ax=axes[0, 0], palette='rainbow')
axes[0, 0].set_title('Tenure')

sns.boxplot(data=df2, x='Churn', y='WarehouseToHome', ax=axes[0, 1], palette='rainbow')
axes[0, 1].set_title('WarehouseToHome')

sns.boxplot(data=df2, x='Churn', y='HourSpendOnApp', ax=axes[1, 0], palette='rainbow')
axes[1, 0].set_title('HourSpendOnApp')

sns.boxplot(data=df2, x='Churn', y='OrderAmountHikeFromlastYear', ax=axes[1, 1], palette='rainbow')
axes[1, 1].set_title('OrderAmountHikeFromlastYear')

sns.boxplot(data=df2, x='Churn', y='CouponUsed', ax=axes[2, 0], palette='rainbow')
axes[2, 0].set_title('CouponUsed')

sns.boxplot(data=df2, x='Churn', y='OrderCount', ax=axes[2, 1], palette='rainbow')
axes[2, 1].set_title('OrderCount')

sns.boxplot(data=df2, x='Churn', y='CashbackAmount', ax=axes[3, 0], palette='rainbow')
axes[3, 0].set_title('CashbackAmount')

# Removing empty subplot
axes[3, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
# cek basic statistics unt numerical columns
print(df.describe())
# Information about data types and non-null counts
print(df.info())
# Out:
#              Churn       Tenure     CityTier  WarehouseToHome  HourSpendOnApp  \
# count  5376.000000  5376.000000  5376.000000      5376.000000     5376.000000
# mean      0.169829     9.841704     1.652902        15.316406        2.929688
# std       0.375517     8.195294     0.914006         8.188123        0.702080
# min       0.000000     0.000000     1.000000         5.000000        1.000000
# 25%       0.000000     2.000000     1.000000         9.000000        2.000000
# 50%       0.000000     9.000000     1.000000        13.000000        3.000000
# 75%       0.000000    15.000000     3.000000        20.000000        3.000000
# max       1.000000    31.000000     3.000000        36.000000        5.000000
#
#        NumberOfDeviceRegistered  SatisfactionScore  NumberOfAddress  \
# count               5376.000000        5376.000000      5376.000000
# mean                   3.675409           3.060640         4.198103
# ...

# %%
# Function to bin numerical columns with custom bin ranges
def bin_numerical_columns(df2):
    # Define custom bin ranges and labels for each numerical column
    custom_bins = {
        'Tenure': [0, 6, 12, 24, 36],  # Example: tenure in months
        'WarehouseToHome': [0, 5, 10, 20, 50],  # Distance in km
        'HourSpendOnApp': [0, 1, 3, 5],  # Time in hours
        'OrderAmountHikeFromlastYear': [0, 5, 10, 15, 20, 30],
        'CouponUsed': [0, 3, 5, 10],
        'OrderCount': [0, 3, 5, 10, 30],
        'CashbackAmount': [0, 50, 100, 150, 200, 250]
    }

    # Define custom labels for each bin (should match the number of intervals)
    custom_labels = {
        'Tenure': ['0-6 months', '6-12 months', '12-24 months', '24-36 months'],
        'WarehouseToHome': ['0-5 km', '5-10 km', '10-20 km', '20-50 km'],
        'HourSpendOnApp': ['0-1 hour', '1-3 hours', '3-5 hours'],
        'OrderAmountHikeFromlastYear': ['0-5 %', '5-10%', '10-15%', '15-20%', '>20%'],
        'CouponUsed': ['0-3', '3-5', '5-10'],
        'OrderCount': ['0-3', '3-5', '5-10', '>10'],
        'CashbackAmount': ['0-50', '50-100', '100-150', '150-200', '>200']
    }

    # Identify numerical columns
    num_cols = df2.select_dtypes(include=['float64']).columns

    # Create bins for each numerical column
    for col in num_cols:
        # Create new bin column
        bin_col_name = col + '_bin 2'

        # Use custom bins and labels if available for the column
        if col in custom_bins:
            bins = custom_bins[col]
            labels = custom_labels[col]
            df2[bin_col_name] = pd.cut(df2[col], bins=bins, labels=labels, include_lowest=True)

    return df2, num_cols

# Function to calculate churn percentage for each bin
def churn_percentage(df2, bin_col):
    churn_data = df2.groupby([bin_col, 'Churn'])['Tenure'].count().unstack(fill_value=0)

    # Cek nama kolom yang ada setelah unstack
    print(churn_data.columns)  # Tambahkan ini untuk melihat nama kolom

    # Pastikan untuk mengakses kolom yang benar berdasarkan nama yang ada
    if 1 in churn_data.columns:
        churn_data['churn_percentage'] = churn_data[1] / churn_data.sum(axis=1) * 100
    else:
        # Jika nama kolom berbeda, sesuaikan akses dengan nama kolom yang benar
        churn_data['churn_percentage'] = churn_data.get('1', 0) / churn_data.sum(axis=1) * 100

    return churn_data


# Bin all numerical columns with custom ranges
df2, num_cols = bin_numerical_columns(df2)

# Plot churn percentage for each binned numerical column
for col in num_cols:
    bin_col_name = col + '_bin 2'

    # Calculate churn percentage for this binned column
    churn_data = churn_percentage(df2, bin_col_name)

    # Plot the churn percentage for this column
    plt.figure(figsize=(10, 6))
    sns.barplot(x=churn_data.index, y=churn_data['churn_percentage'])
    plt.title(f'Churn Percentage by {col.capitalize()}')
    plt.ylabel('Churn Percentage')
    plt.xlabel(f'{col.capitalize()} Bins')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Index([0, 1], dtype='int64', name='Churn')
# Index([0, 1], dtype='int64', name='Churn')
# Index([0, 1], dtype='int64', name='Churn')
# Index([0, 1], dtype='int64', name='Churn')
# Index([0, 1], dtype='int64', name='Churn')
# Index([0, 1], dtype='int64', name='Churn')
# Index([0, 1], dtype='int64', name='Churn')

# %%
# Function to calculate churn percentage for each bin
def churn_percentage(df2, bin_col):
    churn_data = df2.groupby([bin_col, 'Churn'])['Tenure'].count().unstack(fill_value=0)

    # Cek nama kolom yang ada setelah unstack
    print(churn_data.columns)  # Tambahkan ini untuk melihat nama kolom

    # Pastikan untuk mengakses kolom yang benar berdasarkan nama yang ada
    if 1 in churn_data.columns:
        churn_data['churn_percentage'] = churn_data[1] / churn_data.sum(axis=1) * 100
    else:
        # Jika nama kolom berbeda, sesuaikan akses dengan nama kolom yang benar
        churn_data['churn_percentage'] = churn_data.get('1', 0) / churn_data.sum(axis=1) * 100

    return churn_data

# Function to plot churn percentage with labels
def plot_churn_percentage(df2, bin_col_name):
    # Calculate churn percentage for this binned column
    churn_data = churn_percentage(df2, bin_col_name)

    # Plot the churn percentage for this column
    plt.figure(figsize=(10, 6))
    ax = sns.barplot(x=churn_data.index, y=churn_data['churn_percentage'])

    # Set title and labels
    plt.title(f'Churn Percentage by {bin_col_name.capitalize()}')
    plt.ylabel('Churn Percentage (%)')
    plt.xlabel(f'{bin_col_name.capitalize()} Bins')

    # Annotate each bar with the percentage label
    for p in ax.patches:
        height = p.get_height()
        ax.text(
            p.get_x() + p.get_width() / 2,   # x position (center of the bar)
            height + 0.5,                    # y position (slightly above the bar)
            f'{height:.2f}%',                # text label (percentage with 2 decimal places)
            ha="center",                     # horizontal alignment
            fontsize=10                      # font size
        )

    # Show plot
    plt.xticks(rotation=45)
    plt.show()


plot_churn_percentage(df2, 'Tenure_bin 2')
# Out:
# Index([0, 1], dtype='int64', name='Churn')

# %% [markdown]
# Berdasarkan data tenure, diketahui bahwa persentase customer yang churn paling banyak adalah customer yang baru atau dibawah 6 bulan. Diperlukan mekanisme insentif atau retensi bagi pelanggan baru misalkan dengan voucher  free ongkir sampai dengan 3 kali order atau maksimal 15 ribu per order atau dapat disertai juga dengan loyalty poin yang bisa terakumulasi, sehingga diharapkan customer baru dapat di retain sehingga minimal melewati batas 6 bulan awal.

# %%
plot_churn_percentage(df2, 'WarehouseToHome_bin 2')
# Out:
# Index([0, 1], dtype='int64', name='Churn')

# %% [markdown]
# Berdasarkan jarak antara gudang ke pelanggan diketahui bahwa kategori customer dengan jarak yang paling jauh dari gudang memiliki churn rate yang lebih tinggi. Hal tersebut sejalan dengan solusi pada City Tier dimana customer yang jauh dapat diberikan insentif berupa potongan ongkir sd 15 ribu per order. Pada sisi lain juga dapat ditambahkan strategi untuk lebih dekat dengan customer seperti membuat titik kirim / cabang warehouse (memerlukan feasibility lebih lanjut atas hal tersebut).

# %%
plot_churn_percentage(df2, 'HourSpendOnApp_bin 2')
# Out:
# Index([0, 1], dtype='int64', name='Churn')

# %% [markdown]
# Berdasarkan data kategori hours spent on app, tidak terdapat perbedaan yang signifikan antara customer yang menghabiskan waktu 1-3 jam dengan 3-5 jam. Namun demikian pada kategori 3-5 jam tercatat sedikit lebih tinggi churn rate nya. Untuk hal tersebut dapat ditingkatkan performanya dengan adanya fitur yang lebih kaya pada aplikasi misalnya adanya fitur rekomendasi berdasarkan riwayat pencarian customer atau refrensi produk2 yang sedang dicari/dibutuhkan  oleh customer sehingga menghindari adanya effort browsing yang berlebih dari customer

# %%
plot_churn_percentage(df2, 'OrderAmountHikeFromlastYear_bin 2')
# Out:
# Index([0, 1], dtype='int64', name='Churn')

# %% [markdown]
# Berdasarkan data persentase peningkatan order dari tahun lalu ternyata diketahui bahwa customer dengan kategori peningkatan yang tinggi (>20%) memiliki churn rate yang relatif lebih tinggi. Hal tersebut perlu diperbaiki dengan program retensi seperti insentif poin, potongan ongkir dan lain sebagainya.

# %%
plot_churn_percentage(df2, 'CouponUsed_bin 2')
# Out:
# Index([0, 1], dtype='int64', name='Churn')

# %% [markdown]
# Berdasarkan data kupon yang digunakan dapat diketahui juga bahwa churn rate tertinggi berada pada kategori 5 sd 10 kupon. Customer yang suka menggunakan kupon terindikasi akan mudah pindah jika ada penawaran kupon diskon yang lebih menarik dari perusahaan lain. Hal tersebut dapat diantisipasi dengan adanya insentif seperti loyalty poin atau program lainnya seperti customer get customer.

# %%
plot_churn_percentage(df2, 'OrderCount_bin 2')
# Out:
# Index([0, 1], dtype='int64', name='Churn')

# %% [markdown]
# Sejalan dengan beberapa penjelasan sebelumnya data ordercount menunjukkan churn rate berada pada customer yang lebih sedikit pemesanannya. Hal tersebut bisa di perbaiki dengan adanya rentensi bagi customer baru (order masih sedikit)  maupun retensi bagi customer loyal.

# %%
plot_churn_percentage(df2, 'CashbackAmount_bin 2')
# Out:
# Index([0, 1], dtype='int64', name='Churn')

# %% [markdown]
# ### Bonus

# %% [markdown]
# Bagaimana variabel PreferredOrderCategory berkorelasi dengan HoursSpentonApp?

# %%
hour_by_cat = df2[['PreferedOrderCat', 'HourSpendOnApp']].groupby(['PreferedOrderCat', 'HourSpendOnApp']).size().reset_index(name='Total')

#print(hour_by_cat)



# Create a bar plot
fig = px.bar(hour_by_cat,
             x='HourSpendOnApp',
             y='Total',
             color='PreferedOrderCat',
             barmode='group',
             labels={'HourSpendOnApp': 'Hours', 'Total': 'Customers', 'PreferedOrderCat': 'Preferred Order Category'},
             title='Total Hours on Platform by Preferred Order Category')

# Update layout
fig.update_layout(xaxis=dict(tickmode='linear', dtick=1))
fig.update_layout(title={'x':0.45})

# Show the plot
fig.show()

# %% [markdown]
# Total Hours produk elektronik cukup tinggi diantara produk lainnya. Untuk meningkatkan optimalisasi customer experience dalam browsing pada media e-commerce tersebut agar di tambahkan fitur seperti rekomendasi produk sejenis. filtering by brand, by feature, by price.

# %% [markdown]
# Apakah variabel WarehouseToHome mempengaruhi Jumlah pembelian?

# %%
#Warehouse To Home count
warehouse_to_home = df2['WarehouseToHome'].value_counts().reset_index()
warehouse_to_home.columns = ['WarehouseToHome', 'Count']
warehouse_to_home = warehouse_to_home.sort_values('WarehouseToHome')

# Create a scatter and line plot
plt.figure(figsize=(10, 6))
plt.scatter(warehouse_to_home['WarehouseToHome'], warehouse_to_home['Count'], alpha=0.6, color='darkblue')
plt.plot(warehouse_to_home['WarehouseToHome'], warehouse_to_home['Count'], linestyle='-', color='orange')

plt.xlabel('Distance')
plt.ylabel('Total')
plt.title('Warehouse to Home Distance by Total Amount')
plt.grid(which='both', linestyle='None')

# Set x-axis range and ticks
plt.xlim(0, 40)
plt.xticks(range(0, 41, 2))

plt.show()

# %% [markdown]
# Mayoritas pelanggan berlokasi antara 6 hingga 16 km. Semakin jauh jaraknya, semakin sedikit jumlah pelanggan. Jarak tampaknya menjadi faktor penting dalam keputusan pelanggan. Rekomendasi
# 1. Memperluas lokasi gudang untuk mencakup area yang lebih luas berpotensi meningkatkan penjualan dan pendapatan.
# - Pros: Menambah Aset, Menarik pelanggan baru
# - Cons: Butuh biaya yang sangat besar
#
# 2. Menambahkan cashback atau potongan biaya ongkir bagi customer yang berlokasi jauh (lebih dari 20 km) sebesar 5% dari biaya transaksi dengan maksimal potongan sebesar Rp 15.000.
# - Pros: Menambah total pembelian customer
# - Cons: Meningkatkan Beban Biaya Perusahaan, Mengurangi Margin Keuntungan

# %% [markdown]
# ## Machine Learning

# %%
df3=df.copy()

# %% [markdown]
# ### Data Preparation

# %%
for i in df3.columns:
    if df3[i].dtype == 'object':
        print(df3[i].value_counts())
        print(40*"=")
# Out:
# PreferredLoginDevice
# Mobile Phone    3829
# Computer        1547
# Name: count, dtype: int64
# ...
# PreferredPaymentMode
# Debit Card          2202
# Credit Card         1693
# E wallet             587
# Cash on Delivery     491
# Virtual Account      403
# Name: count, dtype: int64
# ...
# Gender
# Male      3231
# Female    2145
# Name: count, dtype: int64
# ...
# PreferedOrderCat
# Electronic    4063
# Fashion        756
# Grocery        342
# Others         215
# Name: count, dtype: int64
# ...
# MaritalStatus
# Married     2838
# Single      1730
# Divorced     808
# Name: count, dtype: int64
# ...

# %%
df3[df3.select_dtypes(exclude=np.number).columns]
# Out:
#      PreferredLoginDevice PreferredPaymentMode  Gender PreferedOrderCat  \
# 0            Mobile Phone           Debit Card  Female       Electronic
# 1            Mobile Phone      Virtual Account    Male       Electronic
# 2            Mobile Phone           Debit Card    Male       Electronic
# 3            Mobile Phone           Debit Card    Male       Electronic
# 4            Mobile Phone          Credit Card    Male       Electronic
# ...                   ...                  ...     ...              ...
# 5625             Computer          Credit Card    Male       Electronic
# 5626         Mobile Phone          Credit Card    Male          Fashion
# 5627         Mobile Phone           Debit Card    Male       Electronic
# 5628             Computer          Credit Card    Male       Electronic
# 5629         Mobile Phone          Credit Card    Male       Electronic
#
#      MaritalStatus
# 0           Single
# 1           Single
# 2           Single
# 3           Single
# ...

# %%
X = df3.drop(columns="Churn")
y = df3['Churn']

# %% [markdown]
# Selanjutnya akan dilihat distribusi data original, data dengan sintesis metode undersampling, data dengan sintesis metode oversampling.

# %%
import pandas as pd
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

# %% [markdown]
# #### Data Original

# %%
print("Proporsi awal data:", Counter(df3['Churn']))
churn_counts_1 = pd.DataFrame.from_dict(Counter(df3['Churn']), orient='index').reset_index()
churn_counts_1.columns = ['Churn', 'Count']

sns.barplot(data=churn_counts_1, x='Churn', y='Count', palette=["blue", "red"])
plt.title('Distribution of Churn')
plt.show()
# Out:
# Proporsi awal data: Counter({0: 4463, 1: 913})

# %% [markdown]
# Data Non-Churn sebanyak 4463, sedangkan Data Churn sebanyak 913.

# %% [markdown]
# #### Data Undersampling

# %%
rus = RandomUnderSampler(random_state=42)
X_resampled_rus, y_resampled_rus = rus.fit_resample(X, y)

print("Setelah Random Undersampling:", Counter(y_resampled_rus))
churn_counts_2 = pd.DataFrame.from_dict(Counter(y_resampled_rus), orient='index').reset_index()
churn_counts_2.columns = ['Churn', 'Count']

sns.barplot(data=churn_counts_2, x='Churn', y='Count', palette=["blue", "red"])
plt.title('Distribution of Churn')
plt.show()
# Out:
# Setelah Random Undersampling: Counter({0: 913, 1: 913})

# %% [markdown]
# Data mengikuti jumlah dari Non-Churn sehingga keduanya memiliki jumlah yang sama di angka 913.

# %% [markdown]
# #### Data Oversampling

# %%
ros = RandomOverSampler(random_state=42)
X_resampled_ros, y_resampled_ros = ros.fit_resample(X, y)

print("Setelah Random Oversampling:", Counter(y_resampled_ros))
churn_counts_3 = pd.DataFrame.from_dict(Counter(y_resampled_ros), orient='index').reset_index()
churn_counts_3.columns = ['Churn', 'Count']

sns.barplot(data=churn_counts_3, x='Churn', y='Count', palette=["blue", "red"])
plt.title('Distribution of Churn')
plt.show()
# Out:
# Setelah Random Oversampling: Counter({1: 4463, 0: 4463})

# %% [markdown]
# Data mengikuti jumlah dari Churn sehingga keduanya memiliki jumlah yang sama di angka 4463.

# %% [markdown]
# Selanjutnya dilakukan Encoding

# %% [markdown]
# #### Encoding

# %% [markdown]
# Kita menggunakan metode Label Encoder untuk mengubah object menjadi numerikal

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for i in df.columns:
    if df3[i].dtype == 'object':
        df3[i]=le.fit_transform(df3[i])

df3.head()
# Out:
#    Churn  Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0      1     4.0                     1         3              6.0
# 1      1     9.0                     1         1              8.0
# 2      1     9.0                     1         1             30.0
# 3      1     0.0                     1         3             15.0
# 4      1     0.0                     1         1             12.0
#
#    PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0                     2       0             3.0                         3
# 1                     4       1             3.0                         4
# 2                     2       1             2.0                         4
# 3                     2       1             2.0                         4
# 4                     1       1             3.0                         3
#
#    PreferedOrderCat  SatisfactionScore  MaritalStatus  NumberOfAddress  \
# ...

# %% [markdown]
# #### Feature Selection

# %% [markdown]
# Feature Selection ini menggunakan metode korelasi dengan korelasi pearson untuk data numerikal dan korelasi spearman untuk data kategorikal

# %%
# Numerik
correlation = df3[['Churn', 'Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'CashbackAmount']].corr(method='pearson')

# Mengambil korelasi antara fitur dan target 'Churn'
target_correlation = correlation['Churn'].drop('Churn')  # Mengabaikan korelasi target dengan dirinya sendiri

# Menampilkan korelasi fitur dengan target
print("Korelasi dengan target 'Churn':\n", target_correlation)

# Visualisasi korelasi fitur dengan target
plt.figure(figsize=(10, 5))
sns.barplot(x=target_correlation.index, y=target_correlation.values)
plt.title('Korelasi Fitur dengan Target (Churn)')
plt.xticks(rotation=90)
plt.show()
# Out:
# Korelasi dengan target 'Churn':
#  Tenure                        -0.339661
# WarehouseToHome                0.062753
# HourSpendOnApp                 0.024131
# OrderAmountHikeFromlastYear   -0.000171
# CouponUsed                    -0.002887
# OrderCount                    -0.020320
# CashbackAmount                -0.162855
# Name: Churn, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming df3 is your dataframe
# df3 = e_comm_df.copy()  # Use the e-commerce dataset

# Define categorical columns and target
categorical_columns = [
    'Churn', 'PreferredLoginDevice', 'CityTier', 'PreferredPaymentMode',
    'Gender', 'NumberOfDeviceRegistered', 'PreferedOrderCat',
    'SatisfactionScore', 'MaritalStatus', 'NumberOfAddress', 'Complain'
]

# Encode categorical columns into numerical values
label_encoders = {}
encoded_data = df3[categorical_columns].copy()

for col in categorical_columns:
    le = LabelEncoder()
    encoded_data[col] = le.fit_transform(df3[col].astype(str))
    label_encoders[col] = le

# Calculate chi-square statistics between 'Churn' and other categorical columns
target = 'Churn'
chi_square_values = {}
for col in categorical_columns:
    if col != target:
        contingency_table = pd.crosstab(encoded_data[target], encoded_data[col])
        chi2, p, _, _ = chi2_contingency(contingency_table)
        chi_square_values[col] = chi2

# Visualize the chi-square values
plt.figure(figsize=(10, 5))
sns.barplot(x=list(chi_square_values.keys()), y=list(chi_square_values.values()))
plt.title('Korelasi ')
plt.xlabel('Features')
plt.ylabel('Chi-Square Value')
plt.xticks(rotation=90)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from scipy.stats import chi2_contingency
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming df3 is your dataframe
# df3 = e_comm_df.copy()  # Use the e-commerce dataset

# Define categorical columns and target
categorical_columns = [
    'Churn', 'PreferredLoginDevice', 'CityTier', 'PreferredPaymentMode',
    'Gender', 'NumberOfDeviceRegistered', 'PreferedOrderCat',
    'SatisfactionScore', 'MaritalStatus', 'NumberOfAddress', 'Complain'
]

# Encode categorical columns into numerical values
label_encoders = {}
encoded_data = df3[categorical_columns].copy()

for col in categorical_columns:
    le = LabelEncoder()
    encoded_data[col] = le.fit_transform(df3[col].astype(str))
    label_encoders[col] = le

# Calculate chi-square statistics between 'Churn' and other categorical columns
target = 'Churn'
chi_square_values = {}
max_chi2 = 0  # Will be used for normalization to the range of -1 to 1

for col in categorical_columns:
    if col != target:
        contingency_table = pd.crosstab(encoded_data[target], encoded_data[col])
        chi2, p, _, _ = chi2_contingency(contingency_table)
        chi_square_values[col] = chi2
        if chi2 > max_chi2:
            max_chi2 = chi2

# Normalize chi-square values to a range between -1 and 1
normalized_chi_square_values = {}
for key, value in chi_square_values.items():
    normalized_value = (value / max_chi2) * 2 - 1  # Normalizes to range from -1 to 1
    normalized_chi_square_values[key] = normalized_value

# Print correlation-like results
print("Chi-Square Normalized Correlation with Target 'Churn':\n")
for feature, value in normalized_chi_square_values.items():
    print(f"{feature}: {value:.2f}")

# Visualize the normalized chi-square values
plt.figure(figsize=(10, 5))
sns.barplot(x=list(normalized_chi_square_values.keys()), y=list(normalized_chi_square_values.values()))
plt.title('Korelasi Fitur dengan Target (Churn)')
plt.xticks(rotation=90)
plt.ylim(-1, 1)
plt.show()
# Out:
# Chi-Square Normalized Correlation with Target 'Churn':
#
# PreferredLoginDevice: -0.91
# CityTier: -0.75
# PreferredPaymentMode: -0.71
# Gender: -0.98
# NumberOfDeviceRegistered: -0.48
# PreferedOrderCat: -0.59
# SatisfactionScore: -0.58
# MaritalStatus: -0.01
# NumberOfAddress: -0.70
# Complain: 1.00

# %%
from sklearn.preprocessing import LabelEncoder
from scipy.stats import chi2_contingency
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Misalkan df3 adalah dataframe Anda
# df3 = e_comm_df.copy()  # Menggunakan dataset e-commerce

# Mendefinisikan kolom kategori dan target
categorical_columns = [
    'Churn', 'PreferredLoginDevice', 'CityTier', 'PreferredPaymentMode',
    'Gender', 'NumberOfDeviceRegistered', 'PreferedOrderCat',
    'SatisfactionScore', 'MaritalStatus', 'NumberOfAddress', 'Complain'
]

# Encode kolom kategori menjadi nilai numerik
label_encoders = {}
encoded_data = df3[categorical_columns].copy()

for col in categorical_columns:
    le = LabelEncoder()
    encoded_data[col] = le.fit_transform(df3[col].astype(str))
    label_encoders[col] = le

# Menghitung statistik Chi-Square antara 'Churn' dan kolom kategori lainnya
target = 'Churn'
chi_square_values = {}

for col in categorical_columns:
    if col != target:
        contingency_table = pd.crosstab(encoded_data[target], encoded_data[col])
        chi2, p, _, _ = chi2_contingency(contingency_table)
        chi_square_values[col] = (chi2, p)

# Menampilkan hasil Chi-Square dengan p-value
print("Chi-Square dengan Target 'Churn' (Chi-Square, p-value):\n")
for feature, (chi2, p) in chi_square_values.items():
    print(f"{feature}: Chi-Square = {chi2:.2f}, p-value = {p:.4f}")

# Visualisasi hasil Chi-Square tanpa normalisasi
chi2_values = [v[0] for v in chi_square_values.values()]
features = list(chi_square_values.keys())

plt.figure(figsize=(10, 5))
sns.barplot(x=features, y=chi2_values)
plt.title('Nilai Chi-Square Fitur terhadap Target (Churn)')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 20
#      18 # Encode kolom kategori menjadi nilai numerik
#      19 label_encoders = {}
# ---> 20 encoded_data = df3[categorical_columns].copy()
#      22 for col in categorical_columns:
#      23     le = LabelEncoder()
#
# NameError: name 'df3' is not defined

# %%
# Kategorikal
correlation = df3[['Churn', 'PreferredLoginDevice', 'CityTier', 'PreferredPaymentMode',
       'Gender', 'NumberOfDeviceRegistered', 'PreferedOrderCat',
       'SatisfactionScore', 'MaritalStatus', 'NumberOfAddress', 'Complain']].corr(method='spearman')

# Mengambil korelasi antara fitur dan target 'Churn'
target_correlation = correlation['Churn'].drop('Churn')  # Mengabaikan korelasi target dengan dirinya sendiri

# Menampilkan korelasi fitur dengan target
print("Korelasi dengan target 'Churn':\n", target_correlation)

# Visualisasi korelasi fitur dengan target
plt.figure(figsize=(10, 5))
sns.barplot(x=target_correlation.index, y=target_correlation.values)
plt.title('Korelasi Fitur dengan Target (Churn)')
plt.xticks(rotation=90)
plt.show()
# Out:
# Korelasi dengan target 'Churn':
#  PreferredLoginDevice       -0.053920
# CityTier                    0.091564
# PreferredPaymentMode        0.008622
# Gender                      0.028612
# NumberOfDeviceRegistered    0.110607
# PreferedOrderCat           -0.098905
# SatisfactionScore           0.109156
# MaritalStatus               0.149572
# NumberOfAddress             0.027449
# Complain                    0.257385
# Name: Churn, dtype: float64

# %% [markdown]
# Untuk kepentingan bisnis, kami tetap memasukkan semua fitur tersebut ke dalam model.

# %% [markdown]
# #### Split Data

# %% [markdown]
# Kami split data dengan perbandingan 80%:20% untuk data training dan testing.

# %%
X = df3.drop(columns="Churn")
y = df3['Churn']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %% [markdown]
# #### Scalling

# %% [markdown]
# Kita melakukan scalling data menggunakan MinMaxScaler dengan harapan data tersebut mendapat hasil yang lebih baik.

# %%
# Scalling
from sklearn.preprocessing import MinMaxScaler , StandardScaler , RobustScaler

scaler = MinMaxScaler()
# SC = StandardScaler()
# Rb = RobustScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %% [markdown]
# #### Modelling

# %% [markdown]
# Kami menggunakan model regresi logistik, Support Vector Machine, Decision Tree, Random Forest, XGboost sebagai Benchmarking yang mana yang terbaik untuk kasus ini.

# %%
# Import necessary libraries
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# Initialize the classifiers
logreg = LogisticRegression()     # Logistic Regression
svm = SVC()                       # Support Vector Machine
dt = DecisionTreeClassifier()     # Decision Tree
rf = RandomForestClassifier()     # Random Forest
xgb = XGBClassifier()  # XGBoost

# %%
# Model Selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV,StratifiedKFold,train_test_split, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
import lightgbm as lgb
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score
from sklearn.metrics import classification_report, roc_auc_score, roc_curve
from sklearn.model_selection import RandomizedSearchCV

# Imbalance Dataset
from imblearn.pipeline import Pipeline
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

# %% [markdown]
# ##### Benchmarking K-Fold

# %%
logit = LogisticRegression()
dt_model = DecisionTreeClassifier()
svm_model = SVC()
xgb_model = XGBClassifier()
rf_model = RandomForestClassifier()

# %%
models = [logit,rf_model,svm_model,xgb_model,dt_model]
score=[]
rata=[]
std=[]

for i in models:
    skfold=StratifiedKFold(n_splits=5)
    estimator=Pipeline([
        ('model',i)])
    model_cv=cross_val_score(estimator,X_train,y_train,cv=skfold,scoring='roc_auc')
    score.append(model_cv)
    rata.append(model_cv.mean())
    std.append(model_cv.std())

pd.DataFrame({'model':['Logistic Regression', 'Random Forest', 'SVM', 'XGBoost', 'Decision Tree'],'mean roc_auc':rata,'sdev':std}).set_index('model').sort_values(by='mean roc_auc',ascending=False)
# Out:
#                      mean roc_auc      sdev
# model
# Random Forest            0.978520  0.006746
# XGBoost                  0.976064  0.006503
# Decision Tree            0.889001  0.023087
# SVM                      0.879763  0.015271
# Logistic Regression      0.875770  0.017609

# %% [markdown]
# Terlihat bahwa model Random Forest adalah yang terbaik untuk roc_aucnya dari setiap model yang menggunakan default hyperparameter.

# %% [markdown]
# ## Benchmarking Testing

# %% [markdown]
# Kita coba untuk setiap kemungkinan data, yaitu data original, data dengan sintesis undersampling dan data dengan sinstesi oversampling dengan harapan mendapat kombinasi terbaik.

# %%
oversampler = RandomOverSampler()
undersampler = RandomUnderSampler()

# %% [markdown]
# Logistic Regression

# %%
# Inisialisasi model dan sampler
logit = LogisticRegression()

# Original Model
pipeline = Pipeline(steps=[('logit_model', logit)])
pipeline.fit(X_train_scaled, y_train)
y_pred_logit = pipeline.predict(X_test_scaled)
logit_report = classification_report(y_test, y_pred_logit, output_dict=True)
logit_report_df = pd.DataFrame(logit_report).transpose()
print("Original" + "-" * 50)
display(logit_report_df)

# Gunakan probabilitas untuk ROC AUC
y_pred_prob_logit = pipeline.predict_proba(X_test_scaled)[:, 1]  # Ambil probabilitas untuk kelas positif
roc_auc_logit = roc_auc_score(y_test, y_pred_prob_logit)
print(f"ROC AUC Score: {roc_auc_logit:.2f}")

# Undersampling
pipeline_1 = Pipeline(steps=[('undersample', undersampler), ('logit_model', logit)])
pipeline_1.fit(X_train_scaled, y_train)
y_pred_logit_RUS = pipeline_1.predict(X_test_scaled)
logit_report_RUS = classification_report(y_test, y_pred_logit_RUS, output_dict=True)
logit_report_df_RUS = pd.DataFrame(logit_report_RUS).transpose()
print("Undersampling" + "-" * 50)
display(logit_report_df_RUS)

# Gunakan probabilitas untuk ROC AUC
y_pred_prob_logit_RUS = pipeline_1.predict_proba(X_test_scaled)[:, 1]
roc_auc_logit_RUS = roc_auc_score(y_test, y_pred_prob_logit_RUS)
print(f"ROC AUC Score: {roc_auc_logit_RUS:.2f}")

# Oversampling
pipeline_2 = Pipeline(steps=[('oversample', oversampler), ('logit_model', logit)])
pipeline_2.fit(X_train_scaled, y_train)
y_pred_logit_ROS = pipeline_2.predict(X_test_scaled)
logit_report_ROS = classification_report(y_test, y_pred_logit_ROS, output_dict=True)
logit_report_df_ROS = pd.DataFrame(logit_report_ROS).transpose()
print("Oversampling" + "-" * 50)
display(logit_report_df_ROS)

# Gunakan probabilitas untuk ROC AUC
y_pred_prob_logit_ROS = pipeline_2.predict_proba(X_test_scaled)[:, 1]
roc_auc_logit_ROS = roc_auc_score(y_test, y_pred_prob_logit_ROS)
print(f"ROC AUC Score: {roc_auc_logit_ROS:.2f}")
# Out:
# Original--------------------------------------------------
#               precision    recall  f1-score      support
# 0              0.881937  0.978723  0.927813   893.000000
# 1              0.776471  0.360656  0.492537   183.000000
# accuracy       0.873606  0.873606  0.873606     0.873606
# macro avg      0.829204  0.669690  0.710175  1076.000000
# weighted avg   0.864000  0.873606  0.853784  1076.000000
# ROC AUC Score: 0.90
# Undersampling--------------------------------------------------
#               precision    recall  f1-score      support
# 0              0.954604  0.824188  0.884615   893.000000
# 1              0.485246  0.808743  0.606557   183.000000
# accuracy       0.821561  0.821561  0.821561     0.821561
# macro avg      0.719925  0.816466  0.745586  1076.000000
# weighted avg   0.874779  0.821561  0.837325  1076.000000
# ROC AUC Score: 0.89
# Oversampling--------------------------------------------------
# ...

# %% [markdown]
# Terbaik pada Undersampling

# %% [markdown]
# Random Forest

# %%
rf_model = RandomForestClassifier()

# Pipeline asli dengan Random Forest
pipeline = Pipeline(steps=[('rf_model', rf_model)])
pipeline.fit(X_train_scaled, y_train)
y_pred_rf = pipeline.predict(X_test_scaled)
rf_report = classification_report(y_test, y_pred_rf, output_dict=True)
rf_report_df = pd.DataFrame(rf_report).transpose()
print("Original" + "-" * 50)
display(rf_report_df)

# Gunakan probabilitas untuk ROC AUC
y_pred_prob_rf = pipeline.predict_proba(X_test_scaled)[:, 1]  # Ambil probabilitas untuk kelas positif
roc_auc_rf = roc_auc_score(y_test, y_pred_prob_rf)
print(f"ROC AUC Score: {roc_auc_rf:.2f}")

# Pipeline dengan Undersampling dan Random Forest
pipeline_1 = Pipeline(steps=[('undersample', undersampler), ('rf_model', rf_model)])
pipeline_1.fit(X_train_scaled, y_train)
y_pred_rf_RUS = pipeline_1.predict(X_test_scaled)
rf_report_RUS = classification_report(y_test, y_pred_rf_RUS, output_dict=True)
rf_report_df_RUS = pd.DataFrame(rf_report_RUS).transpose()
print("Undersampling" + "-" * 50)
display(rf_report_df_RUS)

# Gunakan probabilitas untuk ROC AUC
y_pred_prob_rf_RUS = pipeline_1.predict_proba(X_test_scaled)[:, 1]
roc_auc_rf_RUS = roc_auc_score(y_test, y_pred_prob_rf_RUS)
print(f"ROC AUC Score: {roc_auc_rf_RUS:.2f}")

# Pipeline dengan Oversampling dan Random Forest
pipeline_2 = Pipeline(steps=[('oversample', oversampler), ('rf_model', rf_model)])
pipeline_2.fit(X_train_scaled, y_train)
y_pred_rf_ROS = pipeline_2.predict(X_test_scaled)
rf_report_ROS = classification_report(y_test, y_pred_rf_ROS, output_dict=True)
rf_report_df_ROS = pd.DataFrame(rf_report_ROS).transpose()
print("Oversampling" + "-" * 50)
display(rf_report_df_ROS)

# Gunakan probabilitas untuk ROC AUC
y_pred_prob_rf_ROS = pipeline_2.predict_proba(X_test_scaled)[:, 1]
roc_auc_rf_ROS = roc_auc_score(y_test, y_pred_prob_rf_ROS)
print(f"ROC AUC Score: {roc_auc_rf_ROS:.2f}")
# Out:
# Original--------------------------------------------------
#               precision    recall  f1-score      support
# 0              0.932773  0.994401  0.962602   893.000000
# 1              0.959677  0.650273  0.775244   183.000000
# accuracy       0.935874  0.935874  0.935874     0.935874
# macro avg      0.946225  0.822337  0.868923  1076.000000
# weighted avg   0.937349  0.935874  0.930737  1076.000000
# ROC AUC Score: 0.97
# Undersampling--------------------------------------------------
#               precision    recall  f1-score      support
# 0              0.959620  0.904815  0.931412   893.000000
# 1              0.636752  0.814208  0.714628   183.000000
# accuracy       0.889405  0.889405  0.889405     0.889405
# macro avg      0.798186  0.859511  0.823020  1076.000000
# weighted avg   0.904708  0.889405  0.894543  1076.000000
# ROC AUC Score: 0.95
# Oversampling--------------------------------------------------
# ...

# %% [markdown]
# Terbaik pada oversampling

# %% [markdown]
# SVM

# %%
svm_model = SVC(probability=True)  # Enable probability estimates

# Pipeline asli dengan SVM
pipeline = Pipeline(steps=[('svm_model', svm_model)])
pipeline.fit(X_train_scaled, y_train)

# Predict dan hitung probabilitas untuk ROC AUC
y_pred_svm = pipeline.predict(X_test_scaled)

# Classification report
svm_report = classification_report(y_test, y_pred_svm, output_dict=True)
svm_report_df = pd.DataFrame(svm_report).transpose()
print("Original" + "-" * 50)
display(svm_report_df)

# Hitung ROC AUC Score menggunakan probabilitas
y_pred_prob_svm = pipeline.predict_proba(X_test_scaled)[:, 1]  # Ambil probabilitas untuk kelas positif
roc_auc_svm = roc_auc_score(y_test, y_pred_prob_svm)
print(f"ROC AUC Score: {roc_auc_svm:.2f}")

# Pipeline dengan Undersampling dan SVM
undersampler = RandomUnderSampler()
pipeline_1 = Pipeline(steps=[('undersample', undersampler), ('svm_model', svm_model)])
pipeline_1.fit(X_train_scaled, y_train)

# Predict dan hitung probabilitas untuk ROC AUC
y_pred_svm_RUS = pipeline_1.predict(X_test_scaled)

# Classification report
svm_report_RUS = classification_report(y_test, y_pred_svm_RUS, output_dict=True)
svm_report_df_RUS = pd.DataFrame(svm_report_RUS).transpose()
print("Undersampling" + "-" * 50)
display(svm_report_df_RUS)

# Hitung ROC AUC Score menggunakan probabilitas
y_pred_prob_svm_RUS = pipeline_1.predict_proba(X_test_scaled)[:, 1]
roc_auc_svm_RUS = roc_auc_score(y_test, y_pred_prob_svm_RUS)
print(f"ROC AUC Score: {roc_auc_svm_RUS:.2f}")

# Pipeline dengan Oversampling dan SVM
oversampler = RandomOverSampler()
pipeline_2 = Pipeline(steps=[('oversample', oversampler), ('svm_model', svm_model)])
pipeline_2.fit(X_train_scaled, y_train)

# Predict dan hitung probabilitas untuk ROC AUC
y_pred_svm_ROS = pipeline_2.predict(X_test_scaled)

# Classification report
svm_report_ROS = classification_report(y_test, y_pred_svm_ROS, output_dict=True)
svm_report_df_ROS = pd.DataFrame(svm_report_ROS).transpose()
print("Oversampling" + "-" * 50)
display(svm_report_df_ROS)

# Hitung ROC AUC Score menggunakan probabilitas
y_pred_prob_svm_ROS = pipeline_2.predict_proba(X_test_scaled)[:, 1]
roc_auc_svm_ROS = roc_auc_score(y_test, y_pred_prob_svm_ROS)
print(f"ROC AUC Score: {roc_auc_svm_ROS:.2f}")
# Out:
# Original--------------------------------------------------
#               precision    recall  f1-score      support
# 0              0.897566  0.991041  0.941990   893.000000
# 1              0.911111  0.448087  0.600733   183.000000
# accuracy       0.898699  0.898699  0.898699     0.898699
# macro avg      0.904339  0.719564  0.771362  1076.000000
# weighted avg   0.899870  0.898699  0.883951  1076.000000
# ROC AUC Score: 0.91
# Undersampling--------------------------------------------------
#               precision    recall  f1-score      support
# 0              0.963446  0.826428  0.889693   893.000000
# 1              0.500000  0.846995  0.628803   183.000000
# accuracy       0.829926  0.829926  0.829926     0.829926
# macro avg      0.731723  0.836711  0.759248  1076.000000
# weighted avg   0.884626  0.829926  0.845322  1076.000000
# ROC AUC Score: 0.91
# Oversampling--------------------------------------------------
# ...

# %% [markdown]
# Terbaik pada Oversampling

# %% [markdown]
# XGBoost

# %%
xgb_model = XGBClassifier()  # Menghindari peringatan

# Pipeline asli dengan XGBoost
pipeline = Pipeline(steps=[('xgb_model', xgb_model)])
pipeline.fit(X_train_scaled, y_train)

# Predict dan hitung probabilitas untuk ROC AUC
y_pred_xgb = pipeline.predict(X_test_scaled)

# Classification report
xgb_report = classification_report(y_test, y_pred_xgb, output_dict=True)
xgb_report_df = pd.DataFrame(xgb_report).transpose()
print("Original" + "-" * 50)
display(xgb_report_df)

# Hitung ROC AUC Score menggunakan probabilitas
y_pred_prob_xgb = pipeline.predict_proba(X_test_scaled)[:, 1]  # Ambil probabilitas untuk kelas positif
roc_auc_xgb = roc_auc_score(y_test, y_pred_prob_xgb)
print(f"ROC AUC Score: {roc_auc_xgb:.2f}")

# Pipeline dengan Undersampling dan XGBoost
pipeline_1 = Pipeline(steps=[('undersample', undersampler), ('xgb_model', xgb_model)])
pipeline_1.fit(X_train_scaled, y_train)

# Predict dan hitung probabilitas untuk ROC AUC
y_pred_xgb_RUS = pipeline_1.predict(X_test_scaled)

# Classification report
xgb_report_RUS = classification_report(y_test, y_pred_xgb_RUS, output_dict=True)
xgb_report_df_RUS = pd.DataFrame(xgb_report_RUS).transpose()
print("Undersampling" + "-" * 50)
display(xgb_report_df_RUS)

# Hitung ROC AUC Score menggunakan probabilitas
y_pred_prob_xgb_RUS = pipeline_1.predict_proba(X_test_scaled)[:, 1]
roc_auc_xgb_RUS = roc_auc_score(y_test, y_pred_prob_xgb_RUS)
print(f"ROC AUC Score: {roc_auc_xgb_RUS:.2f}")

# Pipeline dengan Oversampling dan XGBoost
pipeline_2 = Pipeline(steps=[('oversample', oversampler), ('xgb_model', xgb_model)])
pipeline_2.fit(X_train_scaled, y_train)

# Predict dan hitung probabilitas untuk ROC AUC
y_pred_xgb_ROS = pipeline_2.predict(X_test_scaled)

# Classification report
xgb_report_ROS = classification_report(y_test, y_pred_xgb_ROS, output_dict=True)
xgb_report_df_ROS = pd.DataFrame(xgb_report_ROS).transpose()
print("Oversampling" + "-" * 50)
display(xgb_report_df_ROS)

# Hitung ROC AUC Score menggunakan probabilitas
y_pred_prob_xgb_ROS = pipeline_2.predict_proba(X_test_scaled)[:, 1]
roc_auc_xgb_ROS = roc_auc_score(y_test, y_pred_prob_xgb_ROS)
print(f"ROC AUC Score: {roc_auc_xgb_ROS:.2f}")
# Out:
# Original--------------------------------------------------
#               precision    recall  f1-score      support
# 0              0.934737  0.994401  0.963646   893.000000
# 1              0.960317  0.661202  0.783172   183.000000
# accuracy       0.937732  0.937732  0.937732     0.937732
# macro avg      0.947527  0.827802  0.873409  1076.000000
# weighted avg   0.939087  0.937732  0.932952  1076.000000
# ROC AUC Score: 0.96
# Undersampling--------------------------------------------------
#               precision    recall  f1-score      support
# 0              0.953811  0.924972  0.939170   893.000000
# 1              0.680952  0.781421  0.727735   183.000000
# accuracy       0.900558  0.900558  0.900558     0.900558
# macro avg      0.817382  0.853196  0.833453  1076.000000
# weighted avg   0.907404  0.900558  0.903210  1076.000000
# ROC AUC Score: 0.93
# Oversampling--------------------------------------------------
# ...

# %% [markdown]
# Terbaik pada Oversampling

# %% [markdown]
# Decision Tree

# %%
dt_model = DecisionTreeClassifier()

# Pipeline asli dengan Decision Tree
pipeline = Pipeline(steps=[('dt_model', dt_model)])
pipeline.fit(X_train_scaled, y_train)

# Predict dan hitung probabilitas untuk ROC AUC
y_pred_dt = pipeline.predict(X_test_scaled)

# Classification report
dt_report = classification_report(y_test, y_pred_dt, output_dict=True)
dt_report_df = pd.DataFrame(dt_report).transpose()
print("Original" + "-" * 50)
display(dt_report_df)

# Hitung ROC AUC Score menggunakan probabilitas
y_pred_prob_dt = pipeline.predict_proba(X_test_scaled)[:, 1]  # Ambil probabilitas untuk kelas positif
roc_auc_dt = roc_auc_score(y_test, y_pred_prob_dt)
print(f"ROC AUC Score: {roc_auc_dt:.2f}")

# Pipeline dengan Undersampling dan Decision Tree
pipeline_1 = Pipeline(steps=[('undersample', undersampler), ('dt_model', dt_model)])
pipeline_1.fit(X_train_scaled, y_train)

# Predict dan hitung probabilitas untuk ROC AUC
y_pred_dt_RUS = pipeline_1.predict(X_test_scaled)

# Classification report
dt_report_RUS = classification_report(y_test, y_pred_dt_RUS, output_dict=True)
dt_report_df_RUS = pd.DataFrame(dt_report_RUS).transpose()
print("Undersampling" + "-" * 50)
display(dt_report_df_RUS)

# Hitung ROC AUC Score menggunakan probabilitas
y_pred_prob_dt_RUS = pipeline_1.predict_proba(X_test_scaled)[:, 1]
roc_auc_dt_RUS = roc_auc_score(y_test, y_pred_prob_dt_RUS)
print(f"ROC AUC Score: {roc_auc_dt_RUS:.2f}")

# Pipeline dengan Oversampling dan Decision Tree
pipeline_2 = Pipeline(steps=[('oversample', oversampler), ('dt_model', dt_model)])
pipeline_2.fit(X_train_scaled, y_train)

# Predict dan hitung probabilitas untuk ROC AUC
y_pred_dt_ROS = pipeline_2.predict(X_test_scaled)

# Classification report
dt_report_ROS = classification_report(y_test, y_pred_dt_ROS, output_dict=True)
dt_report_df_ROS = pd.DataFrame(dt_report_ROS).transpose()
print("Oversampling" + "-" * 50)
display(dt_report_df_ROS)

# Hitung ROC AUC Score menggunakan probabilitas
y_pred_prob_dt_ROS = pipeline_2.predict_proba(X_test_scaled)[:, 1]
roc_auc_dt_ROS = roc_auc_score(y_test, y_pred_prob_dt_ROS)
print(f"ROC AUC Score: {roc_auc_dt_ROS:.2f}")
# Out:
# Original--------------------------------------------------
#               precision    recall  f1-score      support
# 0              0.929562  0.975364  0.951913   893.000000
# 1              0.841727  0.639344  0.726708   183.000000
# accuracy       0.918216  0.918216  0.918216     0.918216
# macro avg      0.885645  0.807354  0.839310  1076.000000
# weighted avg   0.914624  0.918216  0.913611  1076.000000
# ROC AUC Score: 0.81
# Undersampling--------------------------------------------------
#               precision    recall  f1-score      support
# 0              0.944301  0.816349  0.875676   893.000000
# 1              0.460526  0.765027  0.574949   183.000000
# accuracy       0.807621  0.807621  0.807621     0.807621
# macro avg      0.702413  0.790688  0.725312  1076.000000
# weighted avg   0.862023  0.807621  0.824530  1076.000000
# ROC AUC Score: 0.79
# Oversampling--------------------------------------------------
# ...

# %% [markdown]
# Terbaik pada Original

# %% [markdown]
# Summary Benchmarking

# %%
print("Logistic Regression" + "-" * 50)
display(logit_report_df_RUS)
print("Random Forest" + "-" * 50)
display(rf_report_df_ROS)
print("Support Vector Machine" + "-" * 50)
display(svm_report_df_ROS)
print("XGBoost" + "-" * 50)
display(xgb_report_df_ROS)
print("Decision Tree" + "-" * 50)
display(dt_report_df)
# Out:
# Logistic Regression--------------------------------------------------
#               precision    recall  f1-score      support
# 0              0.954604  0.824188  0.884615   893.000000
# 1              0.485246  0.808743  0.606557   183.000000
# accuracy       0.821561  0.821561  0.821561     0.821561
# macro avg      0.719925  0.816466  0.745586  1076.000000
# weighted avg   0.874779  0.821561  0.837325  1076.000000
# Random Forest--------------------------------------------------
#               precision    recall  f1-score      support
# 0              0.956897  0.994401  0.975288   893.000000
# 1              0.966216  0.781421  0.864048   183.000000
# accuracy       0.958178  0.958178  0.958178     0.958178
# macro avg      0.961556  0.887911  0.919668  1076.000000
# weighted avg   0.958482  0.958178  0.956369  1076.000000
# Support Vector Machine--------------------------------------------------
#               precision    recall  f1-score      support
# ...

# %% [markdown]
# Terlihat kembali lagi model Random Forest adalah yang terbaik performanya pada test data dengan metode RandomOversampling dan Default Hyperparameter.
#
# Mari sekarang kita coba melakukan hyperparameter tuning untuk model RandomForest dengan metode RandomOversampling untuk melihat apakah kita dapat mendapatkan hasil yang lebih baik lagi.
#
# Reference : https://www.analyticsvidhya.com/blog/2021/06/understanding-random-forest/

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# Berikut adalah referensi pemahaman dan pengambilan hyperparameter dari RandomForest:
# - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# - https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74
# - https://www.geeksforgeeks.org/random-forest-hyperparameter-tuning-in-python/

# %% [markdown]
# Metode yang digunakan untuk tuning adalah metode Random Search.
#
# Penelitian oleh Bergstra dan Bengio (2012) dalam makalah mereka, "Random Search for Hyper-Parameter Optimization," menunjukkan bahwa Random Search bisa lebih efektif daripada Grid Search dalam menemukan kombinasi hyperparameter yang optimal, terutama dalam ruang parameter yang besar.

# %%
ros = RandomOverSampler(random_state=42)
rf_model = RandomForestClassifier(random_state=42)

pipeline_rf = Pipeline(steps=[('oversample', ros), ('rf_model', rf_model)])

# %%
param_distributions = {
    'rf_model__n_estimators': [100, 200, 300, 400, 500],
    'rf_model__max_depth': [10, 20, 30, 40, 50],
    'rf_model__min_samples_split': [2, 5, 10],
    'rf_model__min_samples_leaf': [1, 2, 3, 4, 5],
    'rf_model__max_features': ['sqrt', 'log2'],
    'rf_model__bootstrap': [True]
}

# %%
random_search = RandomizedSearchCV(estimator=pipeline_rf, param_distributions=param_distributions,
                                   scoring='roc_auc', cv=StratifiedKFold(n_splits=10, shuffle=True, random_state=42), n_jobs=-1, verbose=2, n_iter=50)

# %%
random_search.fit(X_train_scaled, y_train)

print(random_search.best_params_)
print(random_search.best_score_)
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# {'rf_model__n_estimators': 200, 'rf_model__min_samples_split': 2, 'rf_model__min_samples_leaf': 1, 'rf_model__max_features': 'sqrt', 'rf_model__max_depth': 40, 'rf_model__bootstrap': True}
# 0.9895878899505007

# %%
best_model = random_search.best_estimator_
best_model.fit(X_train_scaled, y_train)
# Out:
# Pipeline(steps=[('oversample', RandomOverSampler(random_state=42)),
#                 ('rf_model',
#                  RandomForestClassifier(max_depth=40, n_estimators=200,
#                                         random_state=42))])

# %%
estimator=Pipeline(steps=[('oversample', ros), ('rf_model', rf_model)])
estimator.fit(X_train_scaled, y_train)
# Out:
# Pipeline(steps=[('oversample', RandomOverSampler(random_state=42)),
#                 ('rf_model', RandomForestClassifier(random_state=42))])

# %%
y_pred_default = estimator.predict(X_test_scaled)
y_pred_proba_default = estimator.predict_proba(X_test_scaled)
y_pred_tuned = best_model.predict(X_test_scaled)
y_pred_proba_tuned = best_model.predict_proba(X_test_scaled)

roc_auc_default = roc_auc_score(y_test, y_pred_proba_default[:,1])
roc_auc_tuned = roc_auc_score(y_test, y_pred_proba_tuned[:,1])

print('ROC AUC Score Default Random Forest : ', roc_auc_default)
print('ROC AUC Score Tuned Random Forest : ', roc_auc_tuned)
# Out:
# ROC AUC Score Default Random Forest :  0.9813271406629583
# ROC AUC Score Tuned Random Forest :  0.9825479289433909

# %% [markdown]
# Terlihat bahwa model Random Forest setelah kita tuning hyperparameternya memiliki nilai ROC AUC yang lebih buruk walaupun hanya naik sedikit saja.
#
# Mari kita lihat juga perbandingan classification reportnya

# %%
report_default = classification_report(y_test, y_pred_default)
report_tuned = classification_report(y_test, y_pred_tuned)

print('Classification Report Default Random Forest : \n', report_default)
print('Classification Report Tuned Random Forest : \n', report_tuned)
# Out:
# Classification Report Default Random Forest :
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       893
#            1       0.96      0.76      0.85       183
#
#     accuracy                           0.95      1076
#    macro avg       0.96      0.88      0.91      1076
# weighted avg       0.95      0.95      0.95      1076
#
# Classification Report Tuned Random Forest :
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       893
#            1       0.97      0.77      0.85       183
#
#     accuracy                           0.96      1076
#    macro avg       0.96      0.88      0.91      1076
# weighted avg       0.96      0.96      0.95      1076

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred_tuned)
sns.heatmap(cm, annot=True, fmt='.0f', cmap=plt.cm.Blues)
plt.xlabel('y_pred')
plt.ylabel('y_actual')
plt.show()

# %% [markdown]
# Terlihat bahwa model Random Forest setelah kita tuning hyperparameternya memiliki classification report yang lebih baik walaupun hanya lebih baik sedikit saja. Oleh karena itu kita akan menggunakan model Random Forest yang sudah di tuned sebagai model akhir kita.

# %% [markdown]
# ## Features Important

# %%
coef1 = pd.Series(best_model['rf_model'].feature_importances_, index=X_train.columns).sort_values(ascending = False).head(10)
coef1.plot(kind='barh', title='Feature Importances')
plt.show()

# %% [markdown]
# Terlihat bahwa untuk model Random Forest yang kita buat, fitur Tenure adalah yang paling penting, diikuti dengan CashbackAmount, WarehouseToHome, dan seterusnya. Fitur Tenure memiliki pengaruh yang jauh lebih besar dibandingkan fitur lainnya, menunjukkan bahwa durasi atau waktu yang dihabiskan pelanggan berhubungan kuat dengan perilaku target (misalnya churn).
#
# Di masa depan, apabila model ini digunakan untuk strategi bisnis yang lebih spesifik, fitur Tenure mungkin perlu diperhatikan dengan saksama, terutama jika model ini bertujuan untuk memprediksi perilaku pelanggan yang baru bergabung. Namun, untuk kali ini, kita akan mengasumsikan bahwa data mengenai Tenure mencerminkan loyalitas pelanggan yang sudah terjalin, sehingga model ini akan lebih relevan digunakan dalam menganalisis strategi retensi pelanggan. Model ini dapat membantu mengidentifikasi pelanggan yang memiliki potensi churn atau pelanggan yang layak diberi penawaran khusus, sehingga strategi pemasaran bisa menjadi lebih efektif dan efisien dalam alokasi sumber daya.
#
# Dengan demikian, model ini akan berperan penting dalam upaya mengurangi biaya retensi pelanggan dan meningkatkan efisiensi operasional dari sisi pemasaran dengan penawaran yang lebih terarah dan strategis.

# %% [markdown]
# **Limitasi**
#
#
# Model bisa memprediksi churn berdasarkan definisi churn diatas 6 bulan, menggunakan terutama 10 parameter terbaik dengan batasan/limit sbb:
#
# 1. Tenure: 0 sd 31 month
# 2. Cashback amount: 37 sd 324 Rupiah
# 3. Warehouse to home: 5 sd 36 KM
# 4. Complain: customer yang ada dan tidak ada kompalain
# 5. Number of Adress: 1 sd 11
# 6. Order Amount Hike from last Year: 11% sd 26%
# 7. Satisfaction Score: 1 sd 5
# 8. Preferred payment mode: Virtual account, ewallet, debit card, credit card dab CoD.
# 9. Marital Status: Single, Married dan Divorced
# 10. Number of device registered: 1 sd 6 device

# %% [markdown]
# ### Error Analytics

# %% [markdown]
# Kita akan menggunakan X_test dan y_test untuk analisa ini karena penggunaan data testing memberikan penilaian yang akurat tentang performa model pada data baru dan tidak terlatih

# %%
y_pred_tuned_train = estimator.predict(X_train)

# %%
y_pred_tuned_test = estimator.predict(X_test)

# %%
y_pred_tuned_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# Buat DataFrame Gabungan
result_df = pd.DataFrame(X_test.copy())

# Menambahkan kolom y_test dan y_pred_tuned_test ke DataFrame
result_df['Actual'] = y_test
result_df['Predicted'] = y_pred_tuned_test

# Tampilkan DataFrame gabungan
print(pd.DataFrame(result_df))
# Out:
#       Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 2700     9.0                     1         3             23.0
# 4311     9.0                     1         3              7.0
# 4691     6.0                     1         1             10.0
# 3455    12.0                     0         1             10.0
# 204     20.0                     1         1             11.0
# ...      ...                   ...       ...              ...
# 3907     1.0                     1         1             16.0
# 2504    12.0                     0         1             10.0
# 3192    27.0                     1         3              7.0
# 2757     3.0                     1         1              7.0
# 3258    19.0                     1         1              9.0
#
#       PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 2700                     3       1             2.0                         4
# ...

# %%
filtered_df = result_df[result_df['Actual'] != result_df['Predicted']]
print(filtered_df)
# Out:
#       Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 4282    20.0                     1         1             21.0
# 5621    14.0                     1         3             35.0
# 4988     1.0                     0         1             15.0
# 3490     1.0                     0         1              5.0
# 202      2.0                     1         3              9.0
# ...      ...                   ...       ...              ...
# 3378     1.0                     1         3             28.0
# 3912     1.0                     1         2             29.0
# 1441     0.0                     1         3              9.0
# 654     14.0                     1         1              9.0
# 3258    19.0                     1         1              9.0
#
#       PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 4282                     2       0             4.0                         4
# ...

# %%
for i in filtered_df:
    countValue_filtered_df = filtered_df[i].value_counts()
    print(f"Feature {i}: {countValue_filtered_df}")
# Out:
# Feature Tenure: Tenure
# 1.0     72
# 0.0     40
# 9.0     20
# 7.0      7
# 3.0      6
# 14.0     6
# 20.0     5
# 2.0      4
# 5.0      3
# 4.0      3
# 11.0     3
# 15.0     2
# 18.0     2
# 13.0     2
# 6.0      2
# 8.0      1
# 16.0     1
# 12.0     1
# 19.0     1
# Name: count, dtype: int64
# Feature PreferredLoginDevice: PreferredLoginDevice
# 1    123
# 0     58
# Name: count, dtype: int64
# Feature CityTier: CityTier
# 1    110
# 3     63
# 2      8
# Name: count, dtype: int64
# Feature WarehouseToHome: WarehouseToHome
# 9.0     35
# 16.0    14
# 14.0    12
# 15.0    10
# 11.0    10
# 29.0     8
# 7.0      7
# 8.0      7
# 10.0     7
# 32.0     6
# 28.0     6
# 31.0     6
# 21.0     5
# 30.0     4
# 18.0     4
# 35.0     4
# 36.0     4
# 13.0     4
# 6.0      4
# 17.0     3
# 12.0     3
# 22.0     3
# 19.0     3
# 20.0     2
# 34.0     2
# 24.0     2
# 5.0      1
# 27.0     1
# 33.0     1
# 25.0     1
# 23.0     1
# 26.0     1
# Name: count, dtype: int64
# ...

# %% [markdown]
# Dari hasil analisis error pada variabel Actual dan Predicted, terlihat bahwa model salah memprediksi sejumlah besar data. Berikut adalah beberapa poin penting dari analisis terhadap fitur-fitur yang paling berkontribusi terhadap kesalahan prediksi:
#
# - Feature Tenure:
#
# Tenure tertinggi yang salah diprediksi adalah 1.0 dengan jumlah 72, diikuti oleh 0.0 sebanyak 40. Hal ini menunjukkan bahwa pengguna dengan masa aktif yang sangat pendek (Tenure rendah) sering salah diprediksi oleh model, kemungkinan karena perilaku pengguna baru yang berbeda dengan pengguna lama belum cukup terdeteksi dengan baik oleh model.
# - Feature PreferredLoginDevice:
#
# Pengguna yang menggunakan perangkat login tertentu, khususnya kategori 1 atau Mobile Phone (dengan 123 kasus), tampaknya lebih sering salah diprediksi. Perangkat login mungkin memengaruhi pola penggunaan yang tidak sepenuhnya dikenali oleh model, sehingga perlu analisis lebih lanjut untuk mengidentifikasi device-specific behavior.
# - Feature CityTier:
#
# Salah prediksi paling banyak terjadi di CityTier 1 dan 3, yang mencakup kota besar dan kota menengah. Ini mengindikasikan kemungkinan adanya perbedaan perilaku belanja yang tidak sepenuhnya dimodelkan, seperti aksesibilitas ke layanan atau preferensi pengguna yang bervariasi berdasarkan lokasi.
# - Feature WarehouseToHome:
#
# Pengiriman dari jarak tertentu seperti 9.0 (dengan 35 kesalahan) sering salah diprediksi. Hal ini bisa menunjukkan ketidaktepatan model dalam mengakomodasi dampak jarak pengiriman terhadap perilaku pembelian atau kepuasan pengguna.
# - Feature PreferredPaymentMode:
#
# Pembayaran yang paling sering salah diprediksi adalah mode pembayaran dengan kode 2 dan 1 atau Debit Card dan Credit Card. Mungkin ada bias yang belum sepenuhnya dimengerti model terkait pilihan pembayaran ini, misalnya, apakah diskon atau cashback lebih sering memicu pembelian berulang.
# - Feature HourSpendOnApp:
#
# Pengguna yang menghabiskan 3 jam di aplikasi (110 kesalahan) tampaknya sering salah diprediksi. Ini menunjukkan bahwa durasi penggunaan aplikasi mungkin memiliki pola perilaku yang rumit, dan mungkin perlu eksplorasi lebih lanjut mengenai aktivitas selama waktu tersebut.
# - Feature NumberOfDeviceRegistered:
#
# Registrasi perangkat terbanyak di kategori 4 (80 kasus) menunjukkan kesalahan prediksi yang cukup besar. Ini mungkin mengindikasikan bahwa pengguna dengan banyak perangkat memiliki pola interaksi yang kompleks atau berbeda dari rata-rata pengguna.
# - Feature SatisfactionScore:
#
# Skor kepuasan 3 (65 kasus) sering salah diprediksi. Hal ini menunjukkan bahwa pengguna dengan tingkat kepuasan sedang cenderung memiliki perilaku yang sulit ditebak oleh model, mungkin karena mereka berada di titik peralihan antara puas dan tidak puas.
# - Feature Complain:
#
# Jumlah kesalahan prediksi cukup merata antara yang memiliki komplain dan tidak. Ini menandakan bahwa model mungkin kurang sensitif terhadap indikasi ketidakpuasan yang diwakili oleh variabel komplain.
# - Feature OrderAmountHikeFromlastYear:
#
# Peningkatan jumlah order tertinggi pada angka 14.0 dan 12.0 menunjukkan kesalahan signifikan, menunjukkan bahwa model kesulitan memprediksi pengguna dengan perubahan pola pembelian yang signifikan dibandingkan tahun sebelumnya.
# - Feature CouponUsed:
#
# Penggunaan kupon 1.0 (83 kasus) menjadi sumber kesalahan terbesar, mungkin karena dampak promosi yang belum diantisipasi secara tepat dalam model prediksi.
# - Feature Actual dan Predicted:
#
# Kesalahan prediksi terutama terjadi pada pengguna yang sebenarnya Churn (Actual 1) tetapi diprediksi tidak Churn (Predicted 0), sebanyak 145 kasus.
#
# Kesimpulan
# Analisis error ini menunjukkan bahwa fitur-fitur seperti Tenure, PreferredLoginDevice, dan jarak pengiriman dari gudang ke rumah memiliki pengaruh signifikan terhadap kesalahan prediksi. Akan tetapi, model ini hanya mengalami kesalahan 181 dari 1076. Pendekatan yang lebih baik untuk menangani variabel-variabel ini, misalnya dengan memasukkan fitur tambahan atau menggunakan algoritma yang lebih kompleks, dapat membantu mengurangi kesalahan prediksi model.

# %%
from sklearn.metrics import confusion_matrix
cm1 = confusion_matrix(y_train, y_pred_tuned_train)
sns.heatmap(cm1, annot=True, fmt='.0f', cmap=plt.cm.Blues)
plt.xlabel('y_pred')
plt.ylabel('y_actual')
plt.show()

# %% [markdown]
# # Conclusion & Recommendation

# %%
print('Classification Report Tuned Random Forest : \n', report_tuned)
# Out:
# Classification Report Tuned Random Forest :
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       893
#            1       0.97      0.77      0.85       183
#
#     accuracy                           0.96      1076
#    macro avg       0.96      0.88      0.91      1076
# weighted avg       0.96      0.96      0.95      1076

# %% [markdown]
# Berdasarkan hasil classification report dari model RF yang sudah dituning, kita dapat menyimpulkan bahwa jika model ini digunakan untuk menyaring pelanggan yang mungkin akan churn, maka model ini dapat mengurangi 99% pelanggan yang tidak akan churn untuk tidak kita beri perhatian lebih (berdasarkan recall untuk kelas 0.0). Selain itu, model ini juga dapat mengidentifikasi 79% dari seluruh pelanggan yang benar-benar akan churn (berdasarkan recall untuk kelas 1.0).
#
# Ketepatan prediksi model kita untuk pelanggan yang akan churn adalah 97% (precision untuk kelas 1.0), yang berarti setiap kali model memprediksi bahwa seorang pelanggan akan churn, sekitar 97% prediksi tersebut benar. Namun, perlu dicatat bahwa ada sekitar 1% dari pelanggan yang tidak akan churn namun diprediksi oleh model sebagai pelanggan yang akan churn, yang dapat mempengaruhi efisiensi strategi retensi.
#
# Secara keseluruhan, model ini memiliki akurasi sebesar 96%, dan performanya dapat dilihat dari weighted average f1-score sebesar 96%, menunjukkan bahwa model seimbang dalam menangani kedua kelas, meskipun ada peluang untuk peningkatan lebih lanjut, khususnya dalam mengurangi kesalahan prediksi untuk pelanggan yang tidak akan churn.

# %% [markdown]
# Dari Context diperoleh bahwa
# - Marketplace besar di Indonesia memiliki CAC yang lebih rendah, di kisaran Rp 100.000 hingga Rp 300.000 per pelanggan.
# - Marketplace kecil atau niche cenderung memiliki CAC yang lebih tinggi, yaitu sekitar Rp 300.000 hingga Rp 1.000.000 per pelanggan.
# - Untuk strategi organik, CAC bisa diturunkan ke Rp 50.000 hingga Rp 150.000 jika kampanye pemasaran organik dijalankan dengan baik.
#
# Bila seandainya biaya untuk screening/menyaring data per kandidat itu Rp 300.000, dan andaikan jumlah pelanggan yang kita miliki untuk suatu kurun waktu sebanyak 200 orang (dimana andaikan 100 orang akan Churn, dan 100 orang tidak akan Churn), maka hitungannya kurang lebih akan seperti ini :
#
# Tanpa Model (semua kandidat diperiksa dan ditawarkan):
#
# - Total Biaya => 200 x Rp 300.000 = Rp 60.000.000
# - Total Pelanggan yang akan Churn => 100 orang (karena semua ditawarkan)
# - Total Pelanggan yang akan Tidak Churn => 0 orang (karena semua ditawarkan)
# - Biaya yang Terbuang => 100 x Rp 300.000 = Rp 30.000.000 (karena 100 orang Churn dan menjadi sia-sia)
# - Jumlah Penghematan => Rp 0
# Dengan Model (hanya pelanggan yang diprediksi Churn (100) oleh model yang diperiksa dan ditawarkan):
#
# - Total Biaya => (79 x Rp 300.000) + (1 x Rp 300.000) = Rp 23.700.000 + Rp 300.000 = Rp 24.000.000
# - Total Pelanggan yang akan Churn => 79 orang (berdasarkan recall untuk kelas churn yaitu 79%)
# - Total Pelanggan yang akan Tidak Churn => 21 orang (karena recall untuk kelas non churn adalah 79%)
# - Biaya yang Terbuang => 1 x Rp 300.000 = Rp 300.000 (berdasarkan recall untuk kelas non churn, sebanyak 1 orang yang tidak Churn tetapi tetap ditawarkan)
# - Jumlah Penghematan => 100 x Rp 300.000 - Rp 300.000 = Rp 29.700.000
#
# Berdasarkan contoh hitungan tersebut, terlihat bahwa dengan menggunakan model prediksi, perusahaan akan dapat menghemat biaya yang signifikan tanpa mengorbankan banyak jumlah pelanggan Tidak Churn. Model ini membantu dalam menyaring pelanggan dengan lebih efisien, mengurangi biaya yang terbuang karena menawarkan pada pelanggan yang tidak tertarik, dan secara keseluruhan meningkatkan efektivitas strategi pemasaran.

# %% [markdown]
# #### Recommendation

# %% [markdown]
# Hal-hal yang bisa dilakukan untuk mengembangkan project dan modelnya lebih baik lagi :
# - Menambahkan fitur-fitur atau kolom baru yang berpotensi berkaitan dengan ketertarikan pelanggan terhadap produk, seperti jumlah biaya transaksi, parameter demografi, dan lainnya, untuk memperkaya analisis dan meningkatkan akurasi prediksi model.
# - Mencoba algorithm ML yang lain terutama neural network, mencoba hyperparameter tuning kembali, dan menggunakan metode Grid Search untuk tuning, serta coba gunakan teknik oversampling yang berbeda juga selain Random Over Sampling, seperti SMOTENC, dll.
# - Menganalisa data-data yang model kita masih salah tebak lebih dalam untuk mengetahui alasannya dan karakteristiknya bagaimana.

# %%
import pickle

# Save as..
model_filename = 'e-commerce_churn.pkl'

with open(model_filename, 'wb') as file:
    pickle.dump(estimator, file)

print(f"Model berhasil disimpan ke dalam file {model_filename}")
# Out:
# Model berhasil disimpan ke dalam file e-commerce_churn.pkl
